# %%
# Install latest pre-release version of bigdl-chronos 
# Installing bigdl-chronos from pip will automatically install pyspark, bigdl, and their dependencies.
# !pip install --pre --upgrade bigdl-chronos[all]
# !pip uninstall -y torchtext # uninstall torchtext to avoid version conflict
exit() # restart the runtime to refresh installed pkg

# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd
import urllib.request
import json
import math

# %%
from bigdl.orca.automl import hp
from bigdl.orca import init_orca_context

# %%
init_orca_context(cores=4, init_ray_on_spark=True)
# Out:
# Initializing orca context
# Current pyspark location is : /usr/local/lib/python3.7/dist-packages/pyspark/__init__.py
# Start to getOrCreate SparkContext
# pyspark_submit_args is:  --driver-class-path /usr/local/lib/python3.7/dist-packages/bigdl/share/dllib/lib/bigdl-dllib-spark_2.4.6-0.14.0-SNAPSHOT-jar-with-dependencies.jar:/usr/local/lib/python3.7/dist-packages/bigdl/share/orca/lib/bigdl-orca-spark_2.4.6-0.14.0-SNAPSHOT-jar-with-dependencies.jar pyspark-shell
# Successfully got a SparkContext
# 2022-01-29 13:22:38,991	INFO services.py:1340 -- View the Ray dashboard at http://172.28.0.2:8265
# {'node_ip_address': '172.28.0.2', 'raylet_ip_address': '172.28.0.2', 'redis_address': '172.28.0.2:6379', 'object_store_address': '/tmp/ray/session_2022-01-29_13-22-35_018708_195/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2022-01-29_13-22-35_018708_195/sockets/raylet', 'webui_url': '172.28.0.2:8265', 'session_dir': '/tmp/ray/session_2022-01-29_13-22-35_018708_195', 'metrics_export_port': 49277, 'node_id': 'fe4e6c1e0b23ffba904834d7876d5ddec291a022567c3f7068b4585c'}
# <SparkContext master=local[4] appName=pyspark-shell>

# %% [markdown]
# ## Get data

# %%
f = open('/content/stock_prices.json')
 
# returns JSON object as
# a dictionary
data = json.load(f)
 
# Iterating through the json
# list
with open('data.json', 'w') as f:
    json.dump(data['data'], f)

data = pd.read_json('data.json')
data
# Out:
#      code       date      time floor  ...      ptValue  change  adChange  pctChange
# 0     VCB 2022-01-20  15:01:03  HOSE  ...            0     0.3    0.3000     0.3456
# 1     VCB 2022-01-19  15:01:02  HOSE  ...  41500000000    -0.8   -0.8000    -0.9132
# 2     VCB 2022-01-18  15:01:03  HOSE  ...   3412500000     1.4    1.4000     1.6241
# 3     VCB 2022-01-17  15:01:03  HOSE  ...   3476541000     2.8    2.8000     3.3573
# 4     VCB 2022-01-14  15:01:03  HOSE  ...   2307000000     1.5    1.5000     1.8315
# ...   ...        ...       ...   ...  ...          ...     ...       ...        ...
# 2254  VCB 2013-01-08  14:01:05  HOSE  ...            0     1.5    0.6310     5.0000
# 2255  VCB 2013-01-07  14:01:04  HOSE  ...            0     0.8    0.3365     2.7397
# 2256  VCB 2013-01-04  14:01:07  HOSE  ...            0     0.7    0.2945     2.4561
# 2257  VCB 2013-01-03  14:01:06  HOSE  ...            0     0.7    0.2945     2.5180
# 2258  VCB 2013-01-02  14:01:04  HOSE  ...            0     0.6    0.2524     2.2059
#
# [2259 rows x 25 columns]

# %%
data.sort_values(by="date", ignore_index=True, inplace=True)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10, 5))
plt.plot(data.date, data.close, color='blue', label='VCB daily price Raw')
plt.xlabel("Time Period")
plt.ylabel("Stock Price")
plt.legend()
plt.show()

# %% [markdown]
# ## Data Pre-processing

# %%
from bigdl.chronos.data import TSDataset
from sklearn.preprocessing import MinMaxScaler

df = data[['date', 'close']]
tsdata_train, tsdata_val, tsdata_test = TSDataset.from_pandas(df, dt_col="date", target_col="close", with_split=True,val_ratio=0.1,test_ratio=0.1)
minmax_scaler = MinMaxScaler()

for tsdata in [tsdata_train, tsdata_val, tsdata_test]:
    tsdata.scale(minmax_scaler, fit=(tsdata is tsdata_train))\
          .roll(lookback=50, horizon=1)

X_train, y_train = tsdata_train.to_numpy()
X_test, y_test = tsdata_test.to_numpy()
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# ((1759, 50, 1), (1759, 1, 1), (175, 50, 1), (175, 1, 1))

# %% [markdown]
# ## Time series forecasting

# %%
from bigdl.chronos.forecaster.lstm_forecaster import LSTMForecaster
# Out:
# /usr/local/lib/python3.7/dist-packages/bigdl/chronos/forecaster/__init__.py:36: UserWarning: Please install `tensorflow<2.0.0` to use MTNetForecaster.
#   warnings.warn("Please install `tensorflow<2.0.0` to use MTNetForecaster.")
# /usr/local/lib/python3.7/dist-packages/bigdl/chronos/forecaster/__init__.py:41: UserWarning: Please install `prophet` to use ProphetForecaster.
#   warnings.warn("Please install `prophet` to use ProphetForecaster.")
# /usr/local/lib/python3.7/dist-packages/bigdl/chronos/forecaster/__init__.py:46: UserWarning: Please install `pmdarima` to use ARIMAForecaster.
#   warnings.warn("Please install `pmdarima` to use ARIMAForecaster.")

# %%
# Hyperparameters
feature_dim = X_train.shape[-1]
target_dim = 1
hidden_dim = 10
learning_rate = 0.01
batch_size = 16
epochs = 50

# %%
forecaster = LSTMForecaster(past_seq_len=X_train.shape[1],
                            input_feature_num=feature_dim,
                            output_feature_num=target_dim,
                            hidden_dim=32,
                            lr=learning_rate,          
                            distributed=True,
                            )
# Out:
# (PytorchRayWorker pid=470) /usr/local/lib/python3.7/dist-packages/bigdl/chronos/forecaster/__init__.py:36: UserWarning: Please install `tensorflow<2.0.0` to use MTNetForecaster.
# (PytorchRayWorker pid=470)   warnings.warn("Please install `tensorflow<2.0.0` to use MTNetForecaster.")
# (PytorchRayWorker pid=470) /usr/local/lib/python3.7/dist-packages/bigdl/chronos/forecaster/__init__.py:41: UserWarning: Please install `prophet` to use ProphetForecaster.
# (PytorchRayWorker pid=470)   warnings.warn("Please install `prophet` to use ProphetForecaster.")
# (PytorchRayWorker pid=470) /usr/local/lib/python3.7/dist-packages/bigdl/chronos/forecaster/__init__.py:46: UserWarning: Please install `pmdarima` to use ARIMAForecaster.
# (PytorchRayWorker pid=470)   warnings.warn("Please install `pmdarima` to use ARIMAForecaster.")
# (PytorchRayWorker pid=470) [2022-01-29 13:50:22] INFO     Added key: store_based_barrier_key:1 to store for rank: 0
# (PytorchRayWorker pid=470) [2022-01-29 13:50:22] INFO     Rank 0: Completed store-based barrier for 1 nodes.
# (PytorchRayWorker pid=470) /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py:65: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
# (PytorchRayWorker pid=470)   "num_layers={}".format(dropout, num_layers))

# %%
forecaster.fit(data=(X_train, y_train), batch_size=batch_size, epochs=epochs)
# Out:
# (PytorchRayWorker pid=470) /usr/local/lib/python3.7/dist-packages/bigdl/chronos/forecaster/utils.py:33: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
# (PytorchRayWorker pid=470)   return DataLoader(TensorDataset(torch.from_numpy(data[0]).float(),
#   0%|          | 0/110 [00:00<?, ?batch/s]
#   1%|          | 1/110 [00:00<00:07, 13.90batch/s, loss=0.158][2022-01-29 13:50:50] INFO     Reducer buckets have been rebuilt in this iteration.
#   2%|▏         | 2/110 [00:00<00:07, 15.05batch/s, loss=0.149]
#   5%|▌         | 6/110 [00:00<00:04, 23.37batch/s, loss=0.0261]
#   8%|▊         | 9/110 [00:00<00:03, 25.29batch/s, loss=0.0211]
#  11%|█         | 12/110 [00:00<00:03, 27.03batch/s, loss=0.041]
#  15%|█▍        | 16/110 [00:00<00:03, 28.68batch/s, loss=0.00831]
#  17%|█▋        | 19/110 [00:00<00:03, 29.50batch/s, loss=0.00864]
#  21%|██        | 23/110 [00:00<00:02, 30.52batch/s, loss=0.00608]
#  24%|██▎       | 26/110 [00:00<00:02, 30.24batch/s, loss=0.0023]
#  27%|██▋       | 30/110 [00:00<00:02, 31.06batch/s, loss=0.00207]
#  31%|███       | 34/110 [00:01<00:02, 31.61batch/s, loss=0.000981]
#  34%|███▎      | 37/110 [00:01<00:02, 31.66batch/s, loss=0.00121]
#  36%|███▋      | 40/110 [00:01<00:02, 31.61batch/s, loss=0.000884]
#  40%|████      | 44/110 [00:01<00:02, 31.67batch/s, loss=0.000697]
#  43%|████▎     | 47/110 [00:01<00:01, 31.87batch/s, loss=0.000282]
#  46%|████▋     | 51/110 [00:01<00:01, 32.00batch/s, loss=0.00128]
#  49%|████▉     | 54/110 [00:01<00:01, 31.95batch/s, loss=0.00117]
#  53%|█████▎    | 58/110 [00:01<00:01, 32.24batch/s, loss=0.000833]
#  55%|█████▌    | 61/110 [00:01<00:01, 32.16batch/s, loss=0.000904]
#  59%|█████▉    | 65/110 [00:02<00:01, 32.37batch/s, loss=0.00183]
#  62%|██████▏   | 68/110 [00:02<00:01, 32.46batch/s, loss=0.00111]
#  65%|██████▍   | 71/110 [00:02<00:01, 32.44batch/s, loss=0.000288]
#  68%|██████▊   | 75/110 [00:02<00:01, 32.47batch/s, loss=0.00036]
#  71%|███████   | 78/110 [00:02<00:00, 32.60batch/s, loss=0.00228]
#  75%|███████▍  | 82/110 [00:02<00:00, 32.77batch/s, loss=0.00118]
#  78%|███████▊  | 86/110 [00:02<00:00, 32.94batch/s, loss=0.000212]
#  81%|████████  | 89/110 [00:02<00:00, 32.90batch/s, loss=0.00177]
#  85%|████████▍ | 93/110 [00:02<00:00, 32.96batch/s, loss=0.000572]
#  87%|████████▋ | 96/110 [00:02<00:00, 32.97batch/s, loss=0.000311]
#  91%|█████████ | 100/110 [00:03<00:00, 33.11batch/s, loss=0.000317]
#  94%|█████████▎| 103/110 [00:03<00:00, 33.20batch/s, loss=0.000885]
#  97%|█████████▋| 107/110 [00:03<00:00, 33.28batch/s, loss=0.00055]
# [2022-01-29 13:50:53] INFO     Finished training epoch 1, stats on rank 0: {'epoch': 1, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.008658889903681447, 'last_train_loss': 0.0002149020874639973}
#   1%|          | 1/110 [00:00<00:02, 37.75batch/s, loss=0.000133]
#   4%|▎         | 4/110 [00:00<00:03, 30.52batch/s, loss=0.000575]
#   7%|▋         | 8/110 [00:00<00:03, 33.72batch/s, loss=0.000746]
#  10%|█         | 11/110 [00:00<00:02, 33.88batch/s, loss=0.000343]
#  14%|█▎        | 15/110 [00:00<00:02, 33.42batch/s, loss=0.000665]
#  16%|█▋        | 18/110 [00:00<00:02, 33.41batch/s, loss=0.00237]
#  20%|██        | 22/110 [00:00<00:02, 33.93batch/s, loss=0.000277]
#  23%|██▎       | 25/110 [00:00<00:02, 33.67batch/s, loss=0.000209]
#  26%|██▋       | 29/110 [00:00<00:02, 33.64batch/s, loss=0.000185]
#  29%|██▉       | 32/110 [00:00<00:02, 33.58batch/s, loss=0.00035]
#  32%|███▏      | 35/110 [00:01<00:02, 33.55batch/s, loss=0.000809]
#  35%|███▌      | 39/110 [00:01<00:02, 33.56batch/s, loss=0.00042]
#  38%|███▊      | 42/110 [00:01<00:02, 33.59batch/s, loss=9.33e-5]
#  41%|████      | 45/110 [00:01<00:01, 33.01batch/s, loss=0.000641]
#  45%|████▍     | 49/110 [00:01<00:01, 33.05batch/s, loss=0.000685]
#  47%|████▋     | 52/110 [00:01<00:01, 32.95batch/s, loss=0.00106]
#  51%|█████     | 56/110 [00:01<00:01, 33.19batch/s, loss=0.000497]
#  54%|█████▎    | 59/110 [00:01<00:01, 33.30batch/s, loss=0.000483]
#  56%|█████▋    | 62/110 [00:01<00:01, 33.19batch/s, loss=0.000516]
#  60%|██████    | 66/110 [00:01<00:01, 33.33batch/s, loss=0.000491]
#  63%|██████▎   | 69/110 [00:02<00:01, 33.28batch/s, loss=0.00122]
#  66%|██████▋   | 73/110 [00:02<00:01, 33.36batch/s, loss=0.000383]
#  69%|██████▉   | 76/110 [00:02<00:01, 33.29batch/s, loss=0.00069]
#  73%|███████▎  | 80/110 [00:02<00:00, 33.35batch/s, loss=0.00046]
#  75%|███████▌  | 83/110 [00:02<00:00, 33.21batch/s, loss=9.41e-5]
#  78%|███████▊  | 86/110 [00:02<00:00, 33.16batch/s, loss=0.000163]
#  81%|████████  | 89/110 [00:02<00:00, 33.18batch/s, loss=0.00056]
#  85%|████████▍ | 93/110 [00:02<00:00, 33.25batch/s, loss=0.000361]
#  87%|████████▋ | 96/110 [00:02<00:00, 33.13batch/s, loss=8.77e-5]
#  90%|█████████ | 99/110 [00:02<00:00, 33.01batch/s, loss=0.000464]
#  93%|█████████▎| 102/110 [00:03<00:00, 33.00batch/s, loss=0.000386]
#  96%|█████████▋| 106/110 [00:03<00:00, 33.11batch/s, loss=0.000416]
# 100%|██████████| 110/110 [00:03<00:00, 33.17batch/s, loss=0.000226]
# [2022-01-29 13:50:56] INFO     Finished training epoch 2, stats on rank 0: {'epoch': 2, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.0005809495594202779, 'last_train_loss': 0.00022630863531958312}
#   3%|▎         | 3/110 [00:00<00:02, 36.93batch/s, loss=0.00116]
#   5%|▌         | 6/110 [00:00<00:03, 34.04batch/s, loss=0.000485]
#   9%|▉         | 10/110 [00:00<00:02, 33.96batch/s, loss=0.000738]
#  12%|█▏        | 13/110 [00:00<00:02, 34.05batch/s, loss=0.000416]
#  15%|█▌        | 17/110 [00:00<00:02, 33.87batch/s, loss=0.000544]
#  18%|█▊        | 20/110 [00:00<00:02, 33.99batch/s, loss=0.000278]
#  22%|██▏       | 24/110 [00:00<00:02, 33.82batch/s, loss=0.000341]
#  25%|██▍       | 27/110 [00:00<00:02, 33.41batch/s, loss=0.000289]
#  27%|██▋       | 30/110 [00:00<00:02, 33.52batch/s, loss=0.000293]
#  31%|███       | 34/110 [00:01<00:02, 33.59batch/s, loss=0.000224]
#  35%|███▍      | 38/110 [00:01<00:02, 33.70batch/s, loss=8.43e-5]
#  37%|███▋      | 41/110 [00:01<00:02, 33.53batch/s, loss=0.000207]
#  40%|████      | 44/110 [00:01<00:01, 33.07batch/s, loss=0.000596]
#  43%|████▎     | 47/110 [00:01<00:01, 33.20batch/s, loss=0.000137]
#  46%|████▋     | 51/110 [00:01<00:01, 33.32batch/s, loss=0.000271]
#  49%|████▉     | 54/110 [00:01<00:01, 33.25batch/s, loss=0.000679]
#  52%|█████▏    | 57/110 [00:01<00:01, 33.31batch/s, loss=0.000882]
#  55%|█████▌    | 61/110 [00:01<00:01, 33.30batch/s, loss=0.000213]
#  58%|█████▊    | 64/110 [00:01<00:01, 33.38batch/s, loss=0.000659]
#  59%|█████▉    | 65/110 [00:01<00:01, 33.39batch/s, loss=0.000715]
#  62%|██████▏   | 68/110 [00:02<00:01, 33.47batch/s, loss=0.000822]
#  65%|██████▍   | 71/110 [00:02<00:01, 33.31batch/s, loss=0.00121]
#  68%|██████▊   | 75/110 [00:02<00:01, 33.31batch/s, loss=0.000953]
#  71%|███████   | 78/110 [00:02<00:00, 33.31batch/s, loss=0.00107]
#  75%|███████▍  | 82/110 [00:02<00:00, 33.49batch/s, loss=0.000637]
#  78%|███████▊  | 86/110 [00:02<00:00, 33.58batch/s, loss=0.000437]
#  81%|████████  | 89/110 [00:02<00:00, 33.60batch/s, loss=0.000598]
#  85%|████████▍ | 93/110 [00:02<00:00, 33.68batch/s, loss=0.000488]
#  87%|████████▋ | 96/110 [00:02<00:00, 33.72batch/s, loss=0.000181]
#  88%|████████▊ | 97/110 [00:02<00:00, 33.74batch/s, loss=0.000787]
#  91%|█████████ | 100/110 [00:02<00:00, 33.72batch/s, loss=0.000304]
#  94%|█████████▎| 103/110 [00:03<00:00, 33.72batch/s, loss=0.000429]
#  97%|█████████▋| 107/110 [00:03<00:00, 33.81batch/s, loss=0.000552]
# [2022-01-29 13:50:59] INFO     Finished training epoch 3, stats on rank 0: {'epoch': 3, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.0005363702827225629, 'last_train_loss': 0.00026920929667539895}
#   0%|          | 0/110 [00:00<?, ?batch/s]
#   4%|▎         | 4/110 [00:00<00:03, 34.59batch/s, loss=0.000496]
#   6%|▋         | 7/110 [00:00<00:03, 33.73batch/s, loss=0.000241]
#  10%|█         | 11/110 [00:00<00:02, 34.05batch/s, loss=0.000261]
#  13%|█▎        | 14/110 [00:00<00:02, 33.41batch/s, loss=0.000381]
#  16%|█▋        | 18/110 [00:00<00:02, 33.66batch/s, loss=0.00233]
#  19%|█▉        | 21/110 [00:00<00:02, 33.61batch/s, loss=0.000227]
#  22%|██▏       | 24/110 [00:00<00:02, 33.25batch/s, loss=0.000293]
#  25%|██▌       | 28/110 [00:00<00:02, 33.63batch/s, loss=0.000246]
#  28%|██▊       | 31/110 [00:00<00:02, 33.50batch/s, loss=0.000274]
#  31%|███       | 34/110 [00:01<00:02, 32.96batch/s, loss=0.000207]
#  34%|███▎      | 37/110 [00:01<00:02, 32.98batch/s, loss=0.000165]
#  37%|███▋      | 41/110 [00:01<00:02, 33.22batch/s, loss=0.000216]
#  40%|████      | 44/110 [00:01<00:02, 32.71batch/s, loss=0.00048]
#  43%|████▎     | 47/110 [00:01<00:01, 32.78batch/s, loss=0.000116]
#  46%|████▋     | 51/110 [00:01<00:01, 32.77batch/s, loss=0.000188]
#  49%|████▉     | 54/110 [00:01<00:01, 32.92batch/s, loss=0.000594]
#  53%|█████▎    | 58/110 [00:01<00:01, 33.06batch/s, loss=0.000648]
#  55%|█████▌    | 61/110 [00:01<00:01, 32.97batch/s, loss=0.000191]
#  59%|█████▉    | 65/110 [00:01<00:01, 33.11batch/s, loss=0.000631]
#  61%|██████    | 67/110 [00:02<00:01, 32.86batch/s, loss=0.0011]
#  65%|██████▍   | 71/110 [00:02<00:01, 32.91batch/s, loss=0.0011]
#  68%|██████▊   | 75/110 [00:02<00:01, 33.12batch/s, loss=0.000855]
#  71%|███████   | 78/110 [00:02<00:00, 33.15batch/s, loss=0.000916]
#  75%|███████▍  | 82/110 [00:02<00:00, 33.27batch/s, loss=0.00052]
#  77%|███████▋  | 85/110 [00:02<00:00, 33.18batch/s, loss=0.000983]
#  81%|████████  | 89/110 [00:02<00:00, 33.31batch/s, loss=0.000555]
#  84%|████████▎ | 92/110 [00:02<00:00, 33.33batch/s, loss=0.000488]
#  87%|████████▋ | 96/110 [00:02<00:00, 33.50batch/s, loss=0.000209]
#  91%|█████████ | 100/110 [00:02<00:00, 33.60batch/s, loss=0.000309]
#  94%|█████████▎| 103/110 [00:03<00:00, 33.53batch/s, loss=0.000379]
#  97%|█████████▋| 107/110 [00:03<00:00, 33.65batch/s, loss=0.000468]
# [2022-01-29 13:51:03] INFO     Finished training epoch 4, stats on rank 0: {'epoch': 4, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.0004787359811674545, 'last_train_loss': 0.0002626990608405322}
#   1%|          | 1/110 [00:00<00:02, 39.31batch/s, loss=0.000143]
#   4%|▎         | 4/110 [00:00<00:03, 35.15batch/s, loss=0.000434]
#   6%|▋         | 7/110 [00:00<00:03, 33.52batch/s, loss=0.000206]
#  10%|█         | 11/110 [00:00<00:02, 34.24batch/s, loss=0.000217]
#  13%|█▎        | 14/110 [00:00<00:02, 33.66batch/s, loss=0.000346]
#  16%|█▋        | 18/110 [00:00<00:02, 33.99batch/s, loss=0.00226]
#  19%|█▉        | 21/110 [00:00<00:02, 33.77batch/s, loss=0.000233]
#  23%|██▎       | 25/110 [00:00<00:02, 34.11batch/s, loss=3.88e-5]
#  25%|██▌       | 28/110 [00:00<00:02, 33.64batch/s, loss=0.000225]
#  29%|██▉       | 32/110 [00:00<00:02, 33.69batch/s, loss=0.000218]
#  32%|███▏      | 35/110 [00:01<00:02, 33.64batch/s, loss=0.000475]
#  35%|███▌      | 39/110 [00:01<00:02, 33.78batch/s, loss=0.00027]
#  38%|███▊      | 42/110 [00:01<00:02, 33.52batch/s, loss=0.000165]
#  41%|████      | 45/110 [00:01<00:01, 33.48batch/s, loss=0.000522]
#  44%|████▎     | 48/110 [00:01<00:01, 33.11batch/s, loss=0.000177]
#  47%|████▋     | 52/110 [00:01<00:01, 33.29batch/s, loss=0.000788]
#  50%|█████     | 55/110 [00:01<00:01, 33.26batch/s, loss=0.00049]
#  53%|█████▎    | 58/110 [00:01<00:01, 33.35batch/s, loss=0.000583]
#  55%|█████▌    | 61/110 [00:01<00:01, 33.02batch/s, loss=0.000169]
#  59%|█████▉    | 65/110 [00:01<00:01, 33.19batch/s, loss=0.000564]
#  63%|██████▎   | 69/110 [00:02<00:01, 33.41batch/s, loss=0.000681]
#  65%|██████▌   | 72/110 [00:02<00:01, 33.45batch/s, loss=0.000731]
#  69%|██████▉   | 76/110 [00:02<00:01, 33.39batch/s, loss=0.000495]
#  72%|███████▏  | 79/110 [00:02<00:00, 33.37batch/s, loss=0.000396]
#  75%|███████▍  | 82/110 [00:02<00:00, 33.37batch/s, loss=0.000467]
#  78%|███████▊  | 86/110 [00:02<00:00, 33.42batch/s, loss=0.000455]
#  81%|████████  | 89/110 [00:02<00:00, 33.45batch/s, loss=0.000539]
#  85%|████████▍ | 93/110 [00:02<00:00, 33.44batch/s, loss=0.000453]
#  87%|████████▋ | 96/110 [00:02<00:00, 33.35batch/s, loss=0.000217]
#  91%|█████████ | 100/110 [00:02<00:00, 33.45batch/s, loss=0.000308]
#  94%|█████████▎| 103/110 [00:03<00:00, 33.29batch/s, loss=0.000307]
#  96%|█████████▋| 106/110 [00:03<00:00, 33.24batch/s, loss=0.000431]
# [2022-01-29 13:51:06] INFO     Finished training epoch 5, stats on rank 0: {'epoch': 5, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.0004394685494080249, 'last_train_loss': 0.00026440073270350695}
#   0%|          | 0/110 [00:00<?, ?batch/s]
#   3%|▎         | 3/110 [00:00<00:03, 35.01batch/s, loss=0.00078]
#   5%|▌         | 6/110 [00:00<00:03, 32.12batch/s, loss=0.000426]
#   9%|▉         | 10/110 [00:00<00:03, 32.84batch/s, loss=0.000474]
#  12%|█▏        | 13/110 [00:00<00:02, 32.89batch/s, loss=0.000282]
#  15%|█▌        | 17/110 [00:00<00:02, 33.35batch/s, loss=0.000562]
#  18%|█▊        | 20/110 [00:00<00:02, 32.80batch/s, loss=0.000258]
#  22%|██▏       | 24/110 [00:00<00:02, 33.08batch/s, loss=0.000271]
#  25%|██▍       | 27/110 [00:00<00:02, 33.33batch/s, loss=0.000174]
#  28%|██▊       | 31/110 [00:00<00:02, 33.36batch/s, loss=0.000321]
#  31%|███       | 34/110 [00:01<00:02, 33.44batch/s, loss=0.000182]
#  34%|███▎      | 37/110 [00:01<00:02, 33.17batch/s, loss=0.000143]
#  37%|███▋      | 41/110 [00:01<00:02, 33.37batch/s, loss=0.000206]
#  41%|████      | 45/110 [00:01<00:01, 33.56batch/s, loss=0.000512]
#  44%|████▎     | 48/110 [00:01<00:01, 33.65batch/s, loss=0.000186]
#  47%|████▋     | 52/110 [00:01<00:01, 33.84batch/s, loss=0.000747]
#  50%|█████     | 55/110 [00:01<00:01, 33.23batch/s, loss=0.000441]
#  53%|█████▎    | 58/110 [00:01<00:01, 33.32batch/s, loss=0.000542]
#  56%|█████▋    | 62/110 [00:01<00:01, 33.47batch/s, loss=0.000289]
#  59%|█████▉    | 65/110 [00:01<00:01, 33.48batch/s, loss=0.000505]
#  63%|██████▎   | 69/110 [00:02<00:01, 33.58batch/s, loss=0.000645]
#  65%|██████▌   | 72/110 [00:02<00:01, 33.53batch/s, loss=0.000659]
#  68%|██████▊   | 75/110 [00:02<00:01, 33.42batch/s, loss=0.000613]
#  72%|███████▏  | 79/110 [00:02<00:00, 33.40batch/s, loss=0.000357]
#  75%|███████▍  | 82/110 [00:02<00:00, 33.41batch/s, loss=0.00044]
#  77%|███████▋  | 85/110 [00:02<00:00, 33.28batch/s, loss=0.000943]
#  80%|████████  | 88/110 [00:02<00:00, 33.17batch/s, loss=0.00138]
#  84%|████████▎ | 92/110 [00:02<00:00, 33.20batch/s, loss=0.000475]
#  86%|████████▋ | 95/110 [00:02<00:00, 33.17batch/s, loss=0.000188]
#  89%|████████▉ | 98/110 [00:02<00:00, 33.06batch/s, loss=0.00029]
#  93%|█████████▎| 102/110 [00:03<00:00, 33.04batch/s, loss=0.000445]
#  95%|█████████▌| 105/110 [00:03<00:00, 33.02batch/s, loss=0.000437]
#  98%|█████████▊| 108/110 [00:03<00:00, 32.98batch/s, loss=0.000198]
# [2022-01-29 13:51:09] INFO     Finished training epoch 6, stats on rank 0: {'epoch': 6, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.00041314900231350694, 'last_train_loss': 0.00027262340881861746}
#   2%|▏         | 2/110 [00:00<00:03, 35.66batch/s, loss=0.000117]
#   5%|▍         | 5/110 [00:00<00:03, 32.56batch/s, loss=0.000441]
#   8%|▊         | 9/110 [00:00<00:03, 32.62batch/s, loss=8.36e-5]
#  11%|█         | 12/110 [00:00<00:03, 32.19batch/s, loss=0.000361]
#  14%|█▎        | 15/110 [00:00<00:02, 32.68batch/s, loss=0.000373]
#  17%|█▋        | 19/110 [00:00<00:02, 33.05batch/s, loss=0.000267]
#  20%|██        | 22/110 [00:00<00:02, 32.94batch/s, loss=0.000262]
#  24%|██▎       | 26/110 [00:00<00:02, 33.38batch/s, loss=0.000212]
#  26%|██▋       | 29/110 [00:00<00:02, 33.33batch/s, loss=6.97e-5]
#  29%|██▉       | 32/110 [00:00<00:02, 33.16batch/s, loss=0.00018]
#  33%|███▎      | 36/110 [00:01<00:02, 33.23batch/s, loss=0.000249]
#  35%|███▌      | 39/110 [00:01<00:02, 33.24batch/s, loss=0.000233]
#  39%|███▉      | 43/110 [00:01<00:02, 33.18batch/s, loss=0.000327]
#  42%|████▏     | 46/110 [00:01<00:01, 32.97batch/s, loss=0.000245]
#  45%|████▍     | 49/110 [00:01<00:01, 33.15batch/s, loss=0.000477]
#  47%|████▋     | 52/110 [00:01<00:01, 32.86batch/s, loss=0.000722]
#  51%|█████     | 56/110 [00:01<00:01, 32.97batch/s, loss=0.000311]
#  54%|█████▎    | 59/110 [00:01<00:01, 32.90batch/s, loss=0.000223]
#  57%|█████▋    | 63/110 [00:01<00:01, 33.01batch/s, loss=0.000291]
#  60%|██████    | 66/110 [00:01<00:01, 33.16batch/s, loss=0.000205]
#  63%|██████▎   | 69/110 [00:02<00:01, 32.98batch/s, loss=0.00062]
#  66%|██████▋   | 73/110 [00:02<00:01, 33.06batch/s, loss=0.000102]
#  69%|██████▉   | 76/110 [00:02<00:01, 33.05batch/s, loss=0.000381]
#  72%|███████▏  | 79/110 [00:02<00:00, 32.94batch/s, loss=0.00032]
#  75%|███████▌  | 83/110 [00:02<00:00, 33.12batch/s, loss=0.000203]
#  79%|███████▉  | 87/110 [00:02<00:00, 33.09batch/s, loss=0.000686]
#  82%|████████▏ | 90/110 [00:02<00:00, 33.14batch/s, loss=0.000744]
#  85%|████████▍ | 93/110 [00:02<00:00, 33.04batch/s, loss=0.000458]
#  88%|████████▊ | 97/110 [00:02<00:00, 33.15batch/s, loss=0.00063]
#  92%|█████████▏| 101/110 [00:03<00:00, 33.24batch/s, loss=0.000807]
#  95%|█████████▍| 104/110 [00:03<00:00, 33.31batch/s, loss=0.000158]
#  97%|█████████▋| 107/110 [00:03<00:00, 33.31batch/s, loss=0.000412]
# [2022-01-29 13:51:13] INFO     Finished training epoch 7, stats on rank 0: {'epoch': 7, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.00039369146180558357, 'last_train_loss': 0.0002826085838023573}
#   1%|          | 1/110 [00:00<00:03, 34.00batch/s, loss=0.000145]
#   4%|▎         | 4/110 [00:00<00:03, 31.03batch/s, loss=0.000368]
#   6%|▋         | 7/110 [00:00<00:03, 30.21batch/s, loss=0.000145]
#   9%|▉         | 10/110 [00:00<00:03, 29.60batch/s, loss=0.000426]
#  12%|█▏        | 13/110 [00:00<00:03, 30.01batch/s, loss=0.000218]
#  15%|█▍        | 16/110 [00:00<00:03, 30.31batch/s, loss=0.0007]
#  18%|█▊        | 20/110 [00:00<00:02, 30.93batch/s, loss=0.000233]
#  21%|██        | 23/110 [00:00<00:02, 30.92batch/s, loss=0.000236]
#  24%|██▎       | 26/110 [00:00<00:02, 31.14batch/s, loss=0.000215]
#  26%|██▋       | 29/110 [00:00<00:02, 31.06batch/s, loss=6.34e-5]
#  27%|██▋       | 30/110 [00:00<00:02, 31.13batch/s, loss=0.00033]
#  30%|███       | 33/110 [00:01<00:02, 31.15batch/s, loss=0.000298]
#  33%|███▎      | 36/110 [00:01<00:02, 31.15batch/s, loss=0.000241]
#  36%|███▋      | 40/110 [00:01<00:02, 31.69batch/s, loss=0.000238]
#  39%|███▉      | 43/110 [00:01<00:02, 31.57batch/s, loss=0.000314]
#  43%|████▎     | 47/110 [00:01<00:01, 31.91batch/s, loss=0.000108]
#  45%|████▍     | 49/110 [00:01<00:01, 31.51batch/s, loss=0.000461]
#  48%|████▊     | 53/110 [00:01<00:01, 31.71batch/s, loss=0.000364]
#  51%|█████     | 56/110 [00:01<00:01, 31.86batch/s, loss=0.0003]
#  54%|█████▎    | 59/110 [00:01<00:01, 31.69batch/s, loss=0.000224]
#  57%|█████▋    | 63/110 [00:01<00:01, 31.87batch/s, loss=0.000284]
#  60%|██████    | 66/110 [00:02<00:01, 31.84batch/s, loss=0.000181]
#  64%|██████▎   | 70/110 [00:02<00:01, 31.91batch/s, loss=0.000376]
#  66%|██████▋   | 73/110 [00:02<00:01, 31.93batch/s, loss=9.93e-5]
#  70%|███████   | 77/110 [00:02<00:01, 32.09batch/s, loss=0.000198]
#  73%|███████▎  | 80/110 [00:02<00:00, 32.12batch/s, loss=0.000593]
#  75%|███████▌  | 83/110 [00:02<00:00, 32.16batch/s, loss=0.000184]
#  79%|███████▉  | 87/110 [00:02<00:00, 32.33batch/s, loss=0.000633]
#  83%|████████▎ | 91/110 [00:02<00:00, 32.45batch/s, loss=0.000794]
#  85%|████████▌ | 94/110 [00:02<00:00, 32.46batch/s, loss=0.000459]
#  89%|████████▉ | 98/110 [00:03<00:00, 32.56batch/s, loss=0.000303]
#  92%|█████████▏| 101/110 [00:03<00:00, 32.60batch/s, loss=0.000808]
#  95%|█████████▍| 104/110 [00:03<00:00, 32.54batch/s, loss=0.000148]
#  97%|█████████▋| 107/110 [00:03<00:00, 32.36batch/s, loss=0.000424]
# [2022-01-29 13:51:16] INFO     Finished training epoch 8, stats on rank 0: {'epoch': 8, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.0003775677943457661, 'last_train_loss': 0.0002910952316597104}
#   1%|          | 1/110 [00:00<00:02, 38.53batch/s, loss=0.000158]
#   4%|▎         | 4/110 [00:00<00:03, 34.40batch/s, loss=0.000366]
#   7%|▋         | 8/110 [00:00<00:03, 33.64batch/s, loss=0.000424]
#  10%|█         | 11/110 [00:00<00:03, 32.89batch/s, loss=0.000187]
#  13%|█▎        | 14/110 [00:00<00:02, 33.14batch/s, loss=0.000279]
#  16%|█▋        | 18/110 [00:00<00:02, 32.83batch/s, loss=0.00216]
#  18%|█▊        | 20/110 [00:00<00:02, 32.35batch/s, loss=0.00022]
#  22%|██▏       | 24/110 [00:00<00:02, 32.21batch/s, loss=0.000223]
#  25%|██▍       | 27/110 [00:00<00:02, 32.21batch/s, loss=0.000145]
#  27%|██▋       | 30/110 [00:00<00:02, 32.11batch/s, loss=0.000324]
#  31%|███       | 34/110 [00:01<00:02, 32.22batch/s, loss=0.000139]
#  34%|███▎      | 37/110 [00:01<00:02, 32.22batch/s, loss=0.000111]
#  37%|███▋      | 41/110 [00:01<00:02, 32.51batch/s, loss=0.000187]
#  40%|████      | 44/110 [00:01<00:02, 32.55batch/s, loss=0.000309]
#  44%|████▎     | 48/110 [00:01<00:01, 32.65batch/s, loss=0.000182]
#  46%|████▋     | 51/110 [00:01<00:01, 32.68batch/s, loss=0.000182]
#  50%|█████     | 55/110 [00:01<00:01, 32.86batch/s, loss=0.000375]
#  53%|█████▎    | 58/110 [00:01<00:01, 33.07batch/s, loss=0.000479]
#  55%|█████▌    | 61/110 [00:01<00:01, 32.90batch/s, loss=0.000115]
#  59%|█████▉    | 65/110 [00:01<00:01, 33.08batch/s, loss=0.000375]
#  63%|██████▎   | 69/110 [00:02<00:01, 33.19batch/s, loss=0.000583]
#  65%|██████▌   | 72/110 [00:02<00:01, 33.18batch/s, loss=0.000536]
#  69%|██████▉   | 76/110 [00:02<00:01, 33.37batch/s, loss=0.000305]
#  72%|███████▏  | 79/110 [00:02<00:00, 33.21batch/s, loss=0.000264]
#  75%|███████▌  | 83/110 [00:02<00:00, 33.45batch/s, loss=0.000166]
#  78%|███████▊  | 86/110 [00:02<00:00, 33.49batch/s, loss=0.000247]
#  82%|████████▏ | 90/110 [00:02<00:00, 33.66batch/s, loss=0.000694]
#  85%|████████▌ | 94/110 [00:02<00:00, 33.67batch/s, loss=0.000447]
#  88%|████████▊ | 97/110 [00:02<00:00, 33.60batch/s, loss=0.000551]
#  92%|█████████▏| 101/110 [00:02<00:00, 33.79batch/s, loss=0.000804]
#  95%|█████████▍| 104/110 [00:03<00:00, 33.83batch/s, loss=0.000143]
#  98%|█████████▊| 108/110 [00:03<00:00, 33.89batch/s, loss=0.0002]
# [2022-01-29 13:51:19] INFO     Finished training epoch 9, stats on rank 0: {'epoch': 9, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.00036317071022141267, 'last_train_loss': 0.00029699920560233295}
#   2%|▏         | 2/110 [00:00<00:02, 37.57batch/s, loss=0.000126]
#   5%|▌         | 6/110 [00:00<00:02, 36.60batch/s, loss=0.00033]
#   8%|▊         | 9/110 [00:00<00:02, 34.07batch/s, loss=8.64e-5]
#  11%|█         | 12/110 [00:00<00:02, 33.99batch/s, loss=0.000327]
#  15%|█▍        | 16/110 [00:00<00:02, 33.85batch/s, loss=0.000649]
#  17%|█▋        | 19/110 [00:00<00:02, 34.06batch/s, loss=0.00026]
#  21%|██        | 23/110 [00:00<00:02, 33.95batch/s, loss=0.0002]
#  24%|██▎       | 26/110 [00:00<00:02, 33.32batch/s, loss=0.000208]
#  26%|██▋       | 29/110 [00:00<00:02, 33.64batch/s, loss=5.11e-5]
#  30%|███       | 33/110 [00:00<00:02, 33.83batch/s, loss=0.000288]
#  34%|███▎      | 37/110 [00:01<00:02, 33.99batch/s, loss=0.000102]
#  36%|███▋      | 40/110 [00:01<00:02, 33.91batch/s, loss=0.000245]
#  39%|███▉      | 43/110 [00:01<00:01, 34.03batch/s, loss=0.000295]
#  43%|████▎     | 47/110 [00:01<00:01, 33.76batch/s, loss=0.000106]
#  45%|████▌     | 50/110 [00:01<00:01, 33.87batch/s, loss=5.45e-5]
#  48%|████▊     | 53/110 [00:01<00:01, 33.81batch/s, loss=0.000341]
#  51%|█████     | 56/110 [00:01<00:01, 33.41batch/s, loss=0.000284]
#  55%|█████▍    | 60/110 [00:01<00:01, 33.60batch/s, loss=0.000254]
#  57%|█████▋    | 63/110 [00:01<00:01, 33.46batch/s, loss=0.000289]
#  61%|██████    | 67/110 [00:02<00:01, 33.48batch/s, loss=0.000337]
#  64%|██████▎   | 70/110 [00:02<00:01, 33.56batch/s, loss=0.000305]
#  67%|██████▋   | 74/110 [00:02<00:01, 33.53batch/s, loss=0.000131]
#  70%|███████   | 77/110 [00:02<00:00, 33.52batch/s, loss=0.000197]
#  73%|███████▎  | 80/110 [00:02<00:00, 33.44batch/s, loss=0.000508]
#  76%|███████▋  | 84/110 [00:02<00:00, 33.48batch/s, loss=0.00114]
#  80%|████████  | 88/110 [00:02<00:00, 33.51batch/s, loss=0.00112]
#  83%|████████▎ | 91/110 [00:02<00:00, 33.41batch/s, loss=0.000677]
#  85%|████████▌ | 94/110 [00:02<00:00, 33.44batch/s, loss=0.000437]
#  88%|████████▊ | 97/110 [00:02<00:00, 33.32batch/s, loss=0.000509]
#  92%|█████████▏| 101/110 [00:03<00:00, 33.42batch/s, loss=0.000799]
#  95%|█████████▍| 104/110 [00:03<00:00, 33.40batch/s, loss=0.000141]
#  98%|█████████▊| 108/110 [00:03<00:00, 33.41batch/s, loss=0.000207]
# [2022-01-29 13:51:22] INFO     Finished training epoch 10, stats on rank 0: {'epoch': 10, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.0003499856414497079, 'last_train_loss': 0.000300591200357303}
#   1%|          | 1/110 [00:00<00:02, 38.01batch/s, loss=0.00018]
#   5%|▍         | 5/110 [00:00<00:03, 34.35batch/s, loss=0.000482]
#   7%|▋         | 8/110 [00:00<00:03, 33.43batch/s, loss=0.000408]
#  11%|█         | 12/110 [00:00<00:02, 33.95batch/s, loss=0.000308]
#  14%|█▎        | 15/110 [00:00<00:02, 33.60batch/s, loss=0.000286]
#  16%|█▋        | 18/110 [00:00<00:02, 33.62batch/s, loss=0.00209]
#  20%|██        | 22/110 [00:00<00:02, 33.50batch/s, loss=0.000209]
#  23%|██▎       | 25/110 [00:00<00:02, 33.34batch/s, loss=9.24e-5]
#  26%|██▋       | 29/110 [00:00<00:02, 33.64batch/s, loss=4.62e-5]
#  29%|██▉       | 32/110 [00:00<00:02, 33.10batch/s, loss=0.000125]
#  31%|███       | 34/110 [00:01<00:02, 32.57batch/s, loss=0.000115]
#  35%|███▍      | 38/110 [00:01<00:02, 32.47batch/s, loss=6.68e-5]
#  37%|███▋      | 41/110 [00:01<00:02, 32.61batch/s, loss=0.000175]
#  40%|████      | 44/110 [00:01<00:02, 32.56batch/s, loss=0.000298]
#  43%|████▎     | 47/110 [00:01<00:01, 32.08batch/s, loss=0.000106]
#  45%|████▌     | 50/110 [00:01<00:01, 31.99batch/s, loss=5.97e-5]
#  48%|████▊     | 53/110 [00:01<00:01, 31.76batch/s, loss=0.000329]
#  51%|█████     | 56/110 [00:01<00:01, 31.81batch/s, loss=0.000279]
#  54%|█████▎    | 59/110 [00:01<00:01, 31.76batch/s, loss=0.000237]
#  57%|█████▋    | 63/110 [00:01<00:01, 31.88batch/s, loss=0.000297]
#  60%|██████    | 66/110 [00:02<00:01, 31.84batch/s, loss=0.000156]
#  64%|██████▎   | 70/110 [00:02<00:01, 32.06batch/s, loss=0.000284]
#  66%|██████▋   | 73/110 [00:02<00:01, 32.11batch/s, loss=9.46e-5]
#  70%|███████   | 77/110 [00:02<00:01, 32.16batch/s, loss=0.00019]
#  73%|███████▎  | 80/110 [00:02<00:00, 32.11batch/s, loss=0.000469]
#  75%|███████▌  | 83/110 [00:02<00:00, 32.12batch/s, loss=0.000139]
#  79%|███████▉  | 87/110 [00:02<00:00, 32.24batch/s, loss=0.000515]
#  82%|████████▏ | 90/110 [00:02<00:00, 32.15batch/s, loss=0.000638]
#  85%|████████▍ | 93/110 [00:02<00:00, 32.21batch/s, loss=0.000389]
#  88%|████████▊ | 97/110 [00:02<00:00, 32.36batch/s, loss=0.00047]
#  91%|█████████ | 100/110 [00:03<00:00, 32.26batch/s, loss=0.000338]
#  94%|█████████▎| 103/110 [00:03<00:00, 32.27batch/s, loss=0.000118]
#  97%|█████████▋| 107/110 [00:03<00:00, 32.29batch/s, loss=0.000458]
# [2022-01-29 13:51:26] INFO     Finished training epoch 11, stats on rank 0: {'epoch': 11, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.00033800279478197825, 'last_train_loss': 0.0003024511970579624}
#   0%|          | 0/110 [00:00<?, ?batch/s]
#   3%|▎         | 3/110 [00:00<00:03, 28.50batch/s, loss=0.000504]
#   5%|▌         | 6/110 [00:00<00:03, 29.97batch/s, loss=0.000285]
#   9%|▉         | 10/110 [00:00<00:03, 31.51batch/s, loss=0.000352]
#  12%|█▏        | 13/110 [00:00<00:03, 31.82batch/s, loss=0.000167]
#  15%|█▍        | 16/110 [00:00<00:02, 32.25batch/s, loss=0.000598]
#  18%|█▊        | 20/110 [00:00<00:02, 32.24batch/s, loss=0.000193]
#  21%|██        | 23/110 [00:00<00:02, 32.27batch/s, loss=0.000166]
#  24%|██▎       | 26/110 [00:00<00:02, 32.41batch/s, loss=0.000196]
#  27%|██▋       | 30/110 [00:00<00:02, 32.38batch/s, loss=0.000301]
#  30%|███       | 33/110 [00:01<00:02, 32.32batch/s, loss=0.00029]
#  33%|███▎      | 36/110 [00:01<00:02, 32.32batch/s, loss=0.000233]
#  35%|███▌      | 39/110 [00:01<00:02, 32.12batch/s, loss=0.000167]
#  39%|███▉      | 43/110 [00:01<00:02, 32.23batch/s, loss=0.000284]
#  42%|████▏     | 46/110 [00:01<00:01, 32.39batch/s, loss=0.000193]
#  45%|████▌     | 50/110 [00:01<00:01, 32.46batch/s, loss=6.58e-5]
#  48%|████▊     | 53/110 [00:01<00:01, 32.59batch/s, loss=0.000318]
#  52%|█████▏    | 57/110 [00:01<00:01, 32.62batch/s, loss=0.000467]
#  55%|█████▍    | 60/110 [00:01<00:01, 32.69batch/s, loss=0.000256]
#  57%|█████▋    | 63/110 [00:01<00:01, 32.45batch/s, loss=0.000305]
#  60%|██████    | 66/110 [00:02<00:01, 32.50batch/s, loss=0.000158]
#  63%|██████▎   | 69/110 [00:02<00:01, 32.31batch/s, loss=0.000541]
#  65%|██████▌   | 72/110 [00:02<00:01, 32.28batch/s, loss=0.000458]
#  66%|██████▋   | 73/110 [00:02<00:01, 32.32batch/s, loss=9.27e-5]
#  69%|██████▉   | 76/110 [00:02<00:01, 32.22batch/s, loss=0.000234]
#  72%|███████▏  | 79/110 [00:02<00:00, 32.36batch/s, loss=0.000229]
#  75%|███████▍  | 82/110 [00:02<00:00, 32.18batch/s, loss=0.000394]
#  78%|███████▊  | 86/110 [00:02<00:00, 32.38batch/s, loss=0.000162]
#  81%|████████  | 89/110 [00:02<00:00, 32.33batch/s, loss=0.000526]
#  85%|████████▍ | 93/110 [00:02<00:00, 32.40batch/s, loss=0.000361]
#  87%|████████▋ | 96/110 [00:02<00:00, 32.45batch/s, loss=0.00017]
#  90%|█████████ | 99/110 [00:03<00:00, 32.44batch/s, loss=0.000285]
#  94%|█████████▎| 103/110 [00:03<00:00, 32.48batch/s, loss=0.000111]
#  96%|█████████▋| 106/110 [00:03<00:00, 32.49batch/s, loss=0.000569]
# [2022-01-29 13:51:29] INFO     Finished training epoch 12, stats on rank 0: {'epoch': 12, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.00032745407379153985, 'last_train_loss': 0.00030307142878882587}
#   0%|          | 0/110 [00:00<?, ?batch/s]
#   3%|▎         | 3/110 [00:00<00:03, 32.50batch/s, loss=0.000465]
#   6%|▋         | 7/110 [00:00<00:03, 33.92batch/s, loss=0.000113]
#   9%|▉         | 10/110 [00:00<00:03, 32.79batch/s, loss=0.000338]
#  13%|█▎        | 14/110 [00:00<00:02, 33.80batch/s, loss=0.000189]
#  15%|█▌        | 17/110 [00:00<00:02, 34.09batch/s, loss=0.000466]
#  18%|█▊        | 20/110 [00:00<00:02, 33.27batch/s, loss=0.00019]
#  22%|██▏       | 24/110 [00:00<00:02, 33.17batch/s, loss=0.000181]
#  25%|██▍       | 27/110 [00:00<00:02, 32.86batch/s, loss=0.000103]
#  28%|██▊       | 31/110 [00:00<00:02, 33.44batch/s, loss=0.000328]
#  31%|███       | 34/110 [00:01<00:02, 33.20batch/s, loss=0.000101]
#  35%|███▍      | 38/110 [00:01<00:02, 33.61batch/s, loss=7.34e-5]
#  37%|███▋      | 41/110 [00:01<00:02, 33.57batch/s, loss=0.000167]
#  41%|████      | 45/110 [00:01<00:01, 33.58batch/s, loss=0.000359]
#  44%|████▎     | 48/110 [00:01<00:01, 33.76batch/s, loss=0.000157]
#  47%|████▋     | 52/110 [00:01<00:01, 33.67batch/s, loss=0.000675]
#  50%|█████     | 55/110 [00:01<00:01, 33.87batch/s, loss=0.000348]
#  53%|█████▎    | 58/110 [00:01<00:01, 33.57batch/s, loss=0.000442]
#  56%|█████▋    | 62/110 [00:01<00:01, 33.60batch/s, loss=0.000182]
#  59%|█████▉    | 65/110 [00:01<00:01, 33.59batch/s, loss=0.000293]
#  63%|██████▎   | 69/110 [00:02<00:01, 33.68batch/s, loss=0.000526]
#  65%|██████▌   | 72/110 [00:02<00:01, 33.77batch/s, loss=0.00044]
#  68%|██████▊   | 75/110 [00:02<00:01, 33.65batch/s, loss=0.000313]
#  72%|███████▏  | 79/110 [00:02<00:00, 33.56batch/s, loss=0.000228]
#  75%|███████▍  | 82/110 [00:02<00:00, 33.31batch/s, loss=0.000384]
#  77%|███████▋  | 85/110 [00:02<00:00, 33.38batch/s, loss=0.00091]
#  81%|████████  | 89/110 [00:02<00:00, 33.52batch/s, loss=0.000513]
#  84%|████████▎ | 92/110 [00:02<00:00, 33.48batch/s, loss=0.00037]
#  87%|████████▋ | 96/110 [00:02<00:00, 33.42batch/s, loss=0.000166]
#  90%|█████████ | 99/110 [00:02<00:00, 33.47batch/s, loss=0.000273]
#  94%|█████████▎| 103/110 [00:03<00:00, 33.43batch/s, loss=0.000104]
#  96%|█████████▋| 106/110 [00:03<00:00, 33.43batch/s, loss=0.000573]
# [2022-01-29 13:51:33] INFO     Finished training epoch 13, stats on rank 0: {'epoch': 13, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.00031864822142563693, 'last_train_loss': 0.0003028912760782987}
#   0%|          | 0/110 [00:00<?, ?batch/s]
#   3%|▎         | 3/110 [00:00<00:03, 31.15batch/s, loss=0.000431]
#   5%|▌         | 6/110 [00:00<00:03, 32.02batch/s, loss=0.000256]
#   9%|▉         | 10/110 [00:00<00:02, 33.61batch/s, loss=0.000328]
#  12%|█▏        | 13/110 [00:00<00:02, 32.82batch/s, loss=0.000163]
#  15%|█▌        | 17/110 [00:00<00:02, 33.68batch/s, loss=0.000464]
#  18%|█▊        | 20/110 [00:00<00:02, 32.91batch/s, loss=0.00019]
#  21%|██        | 23/110 [00:00<00:02, 32.93batch/s, loss=0.000146]
#  25%|██▍       | 27/110 [00:00<00:02, 33.36batch/s, loss=9.76e-5]
#  27%|██▋       | 30/110 [00:00<00:02, 33.13batch/s, loss=0.000286]
#  31%|███       | 34/110 [00:01<00:02, 33.20batch/s, loss=9.64e-5]
#  34%|███▎      | 37/110 [00:01<00:02, 33.02batch/s, loss=7.53e-5]
#  37%|███▋      | 41/110 [00:01<00:02, 33.20batch/s, loss=0.000166]
#  40%|████      | 44/110 [00:01<00:01, 33.06batch/s, loss=0.000295]
#  43%|████▎     | 47/110 [00:01<00:01, 32.97batch/s, loss=0.000106]
#  45%|████▌     | 50/110 [00:01<00:01, 32.84batch/s, loss=7.81e-5]
#  48%|████▊     | 53/110 [00:01<00:01, 32.47batch/s, loss=0.000302]
#  52%|█████▏    | 57/110 [00:01<00:01, 32.78batch/s, loss=0.000442]
#  55%|█████▍    | 60/110 [00:01<00:01, 32.78batch/s, loss=0.000254]
#  58%|█████▊    | 64/110 [00:01<00:01, 32.90batch/s, loss=0.000154]
#  61%|██████    | 67/110 [00:02<00:01, 33.01batch/s, loss=0.000202]
#  65%|██████▍   | 71/110 [00:02<00:01, 33.05batch/s, loss=0.000581]
#  68%|██████▊   | 75/110 [00:02<00:01, 33.19batch/s, loss=0.000308]
#  71%|███████   | 78/110 [00:02<00:00, 33.08batch/s, loss=0.000246]
#  74%|███████▎  | 81/110 [00:02<00:00, 33.12batch/s, loss=0.000512]
#  77%|███████▋  | 85/110 [00:02<00:00, 33.12batch/s, loss=0.000889]
#  80%|████████  | 88/110 [00:02<00:00, 33.02batch/s, loss=0.000986]
#  83%|████████▎ | 91/110 [00:02<00:00, 32.99batch/s, loss=0.000645]
#  86%|████████▋ | 95/110 [00:02<00:00, 33.12batch/s, loss=0.000105]
#  89%|████████▉ | 98/110 [00:02<00:00, 33.14batch/s, loss=0.000288]
#  92%|█████████▏| 101/110 [00:03<00:00, 33.03batch/s, loss=0.000821]
#  95%|█████████▌| 105/110 [00:03<00:00, 33.13batch/s, loss=0.0003]
#  99%|█████████▉| 109/110 [00:03<00:00, 33.20batch/s, loss=0.000211]
# [2022-01-29 13:51:36] INFO     Finished training epoch 14, stats on rank 0: {'epoch': 14, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.00031181034697746546, 'last_train_loss': 0.0003023739845957607}
#   2%|▏         | 2/110 [00:00<00:03, 30.75batch/s, loss=9.56e-5]
#   5%|▍         | 5/110 [00:00<00:03, 33.40batch/s, loss=0.00041]
#   7%|▋         | 8/110 [00:00<00:03, 32.62batch/s, loss=0.00037]
#  11%|█         | 12/110 [00:00<00:02, 32.77batch/s, loss=0.00022]
#  14%|█▎        | 15/110 [00:00<00:02, 32.63batch/s, loss=0.000175]
#  17%|█▋        | 19/110 [00:00<00:02, 33.43batch/s, loss=0.000194]
#  20%|██        | 22/110 [00:00<00:02, 33.37batch/s, loss=0.000185]
#  24%|██▎       | 26/110 [00:00<00:02, 33.72batch/s, loss=0.000189]
#  27%|██▋       | 30/110 [00:00<00:02, 34.16batch/s, loss=0.000279]
#  30%|███       | 33/110 [00:00<00:02, 34.09batch/s, loss=0.000301]
#  34%|███▎      | 37/110 [00:01<00:02, 34.31batch/s, loss=7.23e-5]
#  36%|███▋      | 40/110 [00:01<00:02, 34.31batch/s, loss=0.000254]
#  40%|████      | 44/110 [00:01<00:01, 34.11batch/s, loss=0.000294]
#  43%|████▎     | 47/110 [00:01<00:01, 33.75batch/s, loss=0.000107]
#  45%|████▌     | 50/110 [00:01<00:01, 33.80batch/s, loss=8.33e-5]
#  49%|████▉     | 54/110 [00:01<00:01, 33.75batch/s, loss=0.000556]
#  52%|█████▏    | 57/110 [00:01<00:01, 33.65batch/s, loss=0.000435]
#  55%|█████▍    | 60/110 [00:01<00:01, 33.53batch/s, loss=0.000253]
#  58%|█████▊    | 64/110 [00:01<00:01, 33.68batch/s, loss=0.000157]
#  61%|██████    | 67/110 [00:01<00:01, 33.59batch/s, loss=0.000189]
#  65%|██████▍   | 71/110 [00:02<00:01, 33.79batch/s, loss=0.000571]
#  67%|██████▋   | 74/110 [00:02<00:01, 33.76batch/s, loss=0.00011]
#  71%|███████   | 78/110 [00:02<00:00, 33.86batch/s, loss=0.000212]
#  74%|███████▎  | 81/110 [00:02<00:00, 33.71batch/s, loss=0.000477]
#  76%|███████▋  | 84/110 [00:02<00:00, 33.64batch/s, loss=0.000854]
#  80%|████████  | 88/110 [00:02<00:00, 33.64batch/s, loss=0.000976]
#  83%|████████▎ | 91/110 [00:02<00:00, 33.49batch/s, loss=0.000664]
#  85%|████████▌ | 94/110 [00:02<00:00, 33.53batch/s, loss=0.000393]
#  89%|████████▉ | 98/110 [00:02<00:00, 33.66batch/s, loss=0.000278]
#  93%|█████████▎| 102/110 [00:03<00:00, 33.62batch/s, loss=0.000635]
#  95%|█████████▌| 105/110 [00:03<00:00, 33.67batch/s, loss=0.000297]
#  99%|█████████▉| 109/110 [00:03<00:00, 33.64batch/s, loss=0.000216]
# [2022-01-29 13:51:39] INFO     Finished training epoch 15, stats on rank 0: {'epoch': 15, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.00030697860767005405, 'last_train_loss': 0.0003019625728484243}
#   3%|▎         | 3/110 [00:00<00:02, 37.61batch/s, loss=0.000383]
#   5%|▌         | 6/110 [00:00<00:03, 32.85batch/s, loss=0.00025]
#   8%|▊         | 9/110 [00:00<00:02, 34.03batch/s, loss=9.31e-5]
#  12%|█▏        | 13/110 [00:00<00:02, 33.48batch/s, loss=0.000163]
#  15%|█▍        | 16/110 [00:00<00:02, 34.11batch/s, loss=0.000511]
#  18%|█▊        | 20/110 [00:00<00:02, 33.93batch/s, loss=0.000203]
#  22%|██▏       | 24/110 [00:00<00:02, 34.43batch/s, loss=0.000184]
#  25%|██▍       | 27/110 [00:00<00:02, 34.09batch/s, loss=9.23e-5]
#  28%|██▊       | 31/110 [00:00<00:02, 34.55batch/s, loss=0.000331]
#  31%|███       | 34/110 [00:00<00:02, 34.23batch/s, loss=9.28e-5]
#  35%|███▍      | 38/110 [00:01<00:02, 34.38batch/s, loss=8.88e-5]
#  37%|███▋      | 41/110 [00:01<00:02, 34.24batch/s, loss=0.000167]
#  40%|████      | 44/110 [00:01<00:01, 34.14batch/s, loss=0.000293]
#  44%|████▎     | 48/110 [00:01<00:01, 34.18batch/s, loss=0.000143]
#  46%|████▋     | 51/110 [00:01<00:01, 34.09batch/s, loss=0.000352]
#  50%|█████     | 55/110 [00:01<00:01, 34.21batch/s, loss=0.000327]
#  53%|█████▎    | 58/110 [00:01<00:01, 33.87batch/s, loss=0.00043]
#  55%|█████▌    | 61/110 [00:01<00:01, 34.03batch/s, loss=9.48e-5]
#  59%|█████▉    | 65/110 [00:01<00:01, 34.12batch/s, loss=0.000286]
#  63%|██████▎   | 69/110 [00:02<00:01, 34.14batch/s, loss=0.000473]
#  65%|██████▌   | 72/110 [00:02<00:01, 34.21batch/s, loss=0.000405]
#  69%|██████▉   | 76/110 [00:02<00:00, 34.11batch/s, loss=0.000204]
#  72%|███████▏  | 79/110 [00:02<00:00, 33.97batch/s, loss=0.000245]
#  75%|███████▍  | 82/110 [00:02<00:00, 33.85batch/s, loss=0.000357]
#  78%|███████▊  | 86/110 [00:02<00:00, 33.86batch/s, loss=0.000149]
#  81%|████████  | 89/110 [00:02<00:00, 33.80batch/s, loss=0.000479]
#  85%|████████▍ | 93/110 [00:02<00:00, 33.91batch/s, loss=0.000279]
#  87%|████████▋ | 96/110 [00:02<00:00, 33.82batch/s, loss=0.000171]
#  90%|█████████ | 99/110 [00:02<00:00, 33.81batch/s, loss=0.000234]
#  94%|█████████▎| 103/110 [00:03<00:00, 33.89batch/s, loss=8.14e-5]
#  96%|█████████▋| 106/110 [00:03<00:00, 33.84batch/s, loss=0.000575]
# [2022-01-29 13:51:42] INFO     Finished training epoch 16, stats on rank 0: {'epoch': 16, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.0003039903260794992, 'last_train_loss': 0.0003019674331881106}
#   0%|          | 0/110 [00:00<?, ?batch/s]
#   3%|▎         | 3/110 [00:00<00:03, 31.64batch/s, loss=0.000368]
#   6%|▋         | 7/110 [00:00<00:03, 34.17batch/s, loss=0.000104]
#  10%|█         | 11/110 [00:00<00:02, 35.01batch/s, loss=0.00012]
#  13%|█▎        | 14/110 [00:00<00:02, 34.87batch/s, loss=0.000137]
#  16%|█▋        | 18/110 [00:00<00:02, 34.93batch/s, loss=0.00196]
#  20%|██        | 22/110 [00:00<00:02, 34.83batch/s, loss=0.000181]
#  23%|██▎       | 25/110 [00:00<00:02, 34.90batch/s, loss=0.000123]
#  25%|██▌       | 28/110 [00:00<00:02, 34.50batch/s, loss=0.000161]
#  29%|██▉       | 32/110 [00:00<00:02, 34.56batch/s, loss=8.69e-5]
#  32%|███▏      | 35/110 [00:01<00:02, 34.27batch/s, loss=0.000238]
#  35%|███▍      | 38/110 [00:01<00:02, 33.63batch/s, loss=9.28e-5]
#  38%|███▊      | 42/110 [00:01<00:02, 33.84batch/s, loss=0.000121]
#  41%|████      | 45/110 [00:01<00:01, 33.55batch/s, loss=0.000295]
#  44%|████▎     | 48/110 [00:01<00:01, 33.70batch/s, loss=0.000141]
#  47%|████▋     | 52/110 [00:01<00:01, 33.78batch/s, loss=0.000685]
#  50%|█████     | 55/110 [00:01<00:01, 33.49batch/s, loss=0.000321]
#  53%|█████▎    | 58/110 [00:01<00:01, 33.49batch/s, loss=0.000429]
#  56%|█████▋    | 62/110 [00:01<00:01, 33.37batch/s, loss=0.000171]
#  59%|█████▉    | 65/110 [00:01<00:01, 33.36batch/s, loss=0.000286]
#  62%|██████▏   | 68/110 [00:02<00:01, 33.15batch/s, loss=0.000512]
#  65%|██████▌   | 72/110 [00:02<00:01, 33.26batch/s, loss=0.000397]
#  67%|██████▋   | 74/110 [00:02<00:01, 33.12batch/s, loss=0.000118]
#  71%|███████   | 78/110 [00:02<00:00, 33.18batch/s, loss=0.000171]
#  75%|███████▍  | 82/110 [00:02<00:00, 33.29batch/s, loss=0.000351]
#  77%|███████▋  | 85/110 [00:02<00:00, 33.21batch/s, loss=0.000833]
#  80%|████████  | 88/110 [00:02<00:00, 33.25batch/s, loss=0.000976]
#  84%|████████▎ | 92/110 [00:02<00:00, 33.20batch/s, loss=0.000336]
#  86%|████████▋ | 95/110 [00:02<00:00, 33.28batch/s, loss=9.62e-5]
#  90%|█████████ | 99/110 [00:02<00:00, 33.42batch/s, loss=0.000225]
#  93%|█████████▎| 102/110 [00:03<00:00, 33.26batch/s, loss=0.000615]
#  96%|█████████▋| 106/110 [00:03<00:00, 33.36batch/s, loss=0.000575]
#  99%|█████████▉| 109/110 [00:03<00:00, 33.34batch/s, loss=0.000234]
# 100%|██████████| 110/110 [00:03<00:00, 33.46batch/s, loss=0.000302]
# [2022-01-29 13:51:46] INFO     Finished training epoch 17, stats on rank 0: {'epoch': 17, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.0003025179263005788, 'last_train_loss': 0.00030248460825532675}
#   3%|▎         | 3/110 [00:00<00:03, 34.03batch/s, loss=0.000359]
#   5%|▌         | 6/110 [00:00<00:03, 32.21batch/s, loss=0.000259]
#   9%|▉         | 10/110 [00:00<00:02, 33.60batch/s, loss=0.000304]
#  12%|█▏        | 13/110 [00:00<00:03, 32.32batch/s, loss=0.000165]
#  15%|█▍        | 16/110 [00:00<00:02, 32.17batch/s, loss=0.000483]
#  18%|█▊        | 20/110 [00:00<00:02, 32.79batch/s, loss=0.000226]
#  21%|██        | 23/110 [00:00<00:02, 32.78batch/s, loss=0.000131]
#  24%|██▎       | 26/110 [00:00<00:02, 32.81batch/s, loss=0.000194]
#  26%|██▋       | 29/110 [00:00<00:02, 32.64batch/s, loss=3.25e-5]
#  30%|███       | 33/110 [00:01<00:02, 32.83batch/s, loss=0.000313]
#  33%|███▎      | 36/110 [00:01<00:02, 32.49batch/s, loss=0.000254]
#  36%|███▋      | 40/110 [00:01<00:02, 32.76batch/s, loss=0.000254]
#  39%|███▉      | 43/110 [00:01<00:02, 32.56batch/s, loss=0.000282]
#  42%|████▏     | 46/110 [00:01<00:01, 32.43batch/s, loss=0.000153]
#  45%|████▍     | 49/110 [00:01<00:01, 32.18batch/s, loss=0.000419]
#  47%|████▋     | 52/110 [00:01<00:01, 32.35batch/s, loss=0.000685]
#  51%|█████     | 56/110 [00:01<00:01, 32.42batch/s, loss=0.000283]
#  54%|█████▎    | 59/110 [00:01<00:01, 32.20batch/s, loss=0.000215]
#  56%|█████▋    | 62/110 [00:01<00:01, 32.29batch/s, loss=0.000171]
#  59%|█████▉    | 65/110 [00:02<00:01, 32.11batch/s, loss=0.000287]
#  63%|██████▎   | 69/110 [00:02<00:01, 32.33batch/s, loss=0.000447]
#  65%|██████▌   | 72/110 [00:02<00:01, 32.50batch/s, loss=0.000392]
#  69%|██████▉   | 76/110 [00:02<00:01, 32.47batch/s, loss=0.000203]
#  72%|███████▏  | 79/110 [00:02<00:00, 32.53batch/s, loss=0.000262]
#  75%|███████▌  | 83/110 [00:02<00:00, 32.53batch/s, loss=0.000141]
#  79%|███████▉  | 87/110 [00:02<00:00, 32.72batch/s, loss=0.000494]
#  82%|████████▏ | 90/110 [00:02<00:00, 32.69batch/s, loss=0.000525]
#  85%|████████▍ | 93/110 [00:02<00:00, 32.59batch/s, loss=0.000262]
#  87%|████████▋ | 96/110 [00:02<00:00, 32.59batch/s, loss=0.000182]
#  91%|█████████ | 100/110 [00:03<00:00, 32.66batch/s, loss=0.000386]
#  95%|█████████▍| 104/110 [00:03<00:00, 32.78batch/s, loss=0.000123]
#  97%|█████████▋| 107/110 [00:03<00:00, 32.75batch/s, loss=0.00037]
# [2022-01-29 13:51:49] INFO     Finished training epoch 18, stats on rank 0: {'epoch': 18, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.00030214283277488175, 'last_train_loss': 0.00030343487742356956}
#   1%|          | 1/110 [00:00<00:02, 38.66batch/s, loss=0.000155]
#   4%|▎         | 4/110 [00:00<00:03, 30.77batch/s, loss=0.000394]
#   7%|▋         | 8/110 [00:00<00:03, 32.91batch/s, loss=0.000347]
#  10%|█         | 11/110 [00:00<00:03, 32.64batch/s, loss=0.000112]
#  13%|█▎        | 14/110 [00:00<00:02, 32.62batch/s, loss=0.000127]
#  15%|█▌        | 17/110 [00:00<00:02, 31.78batch/s, loss=0.000472]
#  18%|█▊        | 20/110 [00:00<00:02, 31.35batch/s, loss=0.000237]
#  22%|██▏       | 24/110 [00:00<00:02, 31.82batch/s, loss=0.000207]
#  25%|██▍       | 27/110 [00:00<00:02, 31.90batch/s, loss=9.02e-5]
#  27%|██▋       | 30/110 [00:00<00:02, 32.18batch/s, loss=0.000268]
#  31%|███       | 34/110 [00:01<00:02, 32.12batch/s, loss=9.31e-5]
#  34%|███▎      | 37/110 [00:01<00:02, 32.34batch/s, loss=6.72e-5]
#  37%|███▋      | 41/110 [00:01<00:02, 32.79batch/s, loss=0.00017]
#  40%|████      | 44/110 [00:01<00:02, 32.79batch/s, loss=0.00029]
#  44%|████▎     | 48/110 [00:01<00:01, 33.08batch/s, loss=0.000139]
#  46%|████▋     | 51/110 [00:01<00:01, 32.51batch/s, loss=0.000377]
#  49%|████▉     | 54/110 [00:01<00:01, 32.52batch/s, loss=0.000588]
#  53%|█████▎    | 58/110 [00:01<00:01, 32.75batch/s, loss=0.00043]
#  55%|█████▌    | 61/110 [00:01<00:01, 32.58batch/s, loss=9.97e-5]
#  58%|█████▊    | 64/110 [00:01<00:01, 32.58batch/s, loss=0.000169]
#  61%|██████    | 67/110 [00:02<00:01, 32.31batch/s, loss=0.000172]
#  65%|██████▍   | 71/110 [00:02<00:01, 32.43batch/s, loss=0.000564]
#  67%|██████▋   | 74/110 [00:02<00:01, 32.37batch/s, loss=0.000126]
#  71%|███████   | 78/110 [00:02<00:00, 32.47batch/s, loss=0.000154]
#  74%|███████▎  | 81/110 [00:02<00:00, 32.38batch/s, loss=0.000401]
#  76%|███████▋  | 84/110 [00:02<00:00, 32.27batch/s, loss=0.00083]
#  79%|███████▉  | 87/110 [00:02<00:00, 32.32batch/s, loss=0.000502]
#  82%|████████▏ | 90/110 [00:02<00:00, 32.23batch/s, loss=0.000523]
#  85%|████████▌ | 94/110 [00:02<00:00, 32.35batch/s, loss=0.000375]
#  88%|████████▊ | 97/110 [00:03<00:00, 32.32batch/s, loss=0.000349]
#  91%|█████████ | 100/110 [00:03<00:00, 32.33batch/s, loss=0.000385]
#  95%|█████████▍| 104/110 [00:03<00:00, 32.29batch/s, loss=0.000122]
#  97%|█████████▋| 107/110 [00:03<00:00, 32.36batch/s, loss=0.000359]
# [2022-01-29 13:51:52] INFO     Finished training epoch 19, stats on rank 0: {'epoch': 19, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.00030244768649734656, 'last_train_loss': 0.00030470185447484255}
#   1%|          | 1/110 [00:00<00:03, 31.37batch/s, loss=0.00015]
#   4%|▎         | 4/110 [00:00<00:03, 33.32batch/s, loss=0.000398]
#   7%|▋         | 8/110 [00:00<00:03, 33.93batch/s, loss=0.000346]
#  10%|█         | 11/110 [00:00<00:02, 33.15batch/s, loss=0.00011]
#  13%|█▎        | 14/110 [00:00<00:02, 33.15batch/s, loss=0.000124]
#  16%|█▋        | 18/110 [00:00<00:02, 33.25batch/s, loss=0.00194]
#  19%|█▉        | 21/110 [00:00<00:02, 33.53batch/s, loss=0.000216]
#  22%|██▏       | 24/110 [00:00<00:02, 32.95batch/s, loss=0.000214]
#  25%|██▌       | 28/110 [00:00<00:02, 33.19batch/s, loss=0.000162]
#  28%|██▊       | 31/110 [00:00<00:02, 33.19batch/s, loss=0.000334]
#  31%|███       | 34/110 [00:01<00:02, 32.72batch/s, loss=9.35e-5]
#  34%|███▎      | 37/110 [00:01<00:02, 32.72batch/s, loss=6.68e-5]
#  36%|███▋      | 40/110 [00:01<00:02, 32.18batch/s, loss=0.000252]
#  40%|████      | 44/110 [00:01<00:02, 32.36batch/s, loss=0.00029]
#  43%|████▎     | 47/110 [00:01<00:01, 32.41batch/s, loss=0.000111]
#  46%|████▋     | 51/110 [00:01<00:01, 32.65batch/s, loss=0.000381]
#  49%|████▉     | 54/110 [00:01<00:01, 32.46batch/s, loss=0.000594]
#  53%|█████▎    | 58/110 [00:01<00:01, 32.58batch/s, loss=0.000431]
#  55%|█████▌    | 61/110 [00:01<00:01, 32.58batch/s, loss=0.000101]
#  58%|█████▊    | 64/110 [00:01<00:01, 32.46batch/s, loss=0.00017]
#  62%|██████▏   | 68/110 [00:02<00:01, 32.55batch/s, loss=0.000514]
#  65%|██████▍   | 71/110 [00:02<00:01, 32.55batch/s, loss=0.000565]
#  67%|██████▋   | 74/110 [00:02<00:01, 32.59batch/s, loss=0.000128]
#  71%|███████   | 78/110 [00:02<00:00, 32.66batch/s, loss=0.00015]
#  74%|███████▎  | 81/110 [00:02<00:00, 32.60batch/s, loss=0.000394]
#  77%|███████▋  | 85/110 [00:02<00:00, 32.72batch/s, loss=0.000795]
#  81%|████████  | 89/110 [00:02<00:00, 32.78batch/s, loss=0.000468]
#  84%|████████▎ | 92/110 [00:02<00:00, 32.86batch/s, loss=0.00034]
# ...
#  43%|████▎     | 47/110 [00:01<00:01, 33.11batch/s, loss=0.000132]
#  45%|████▌     | 50/110 [00:01<00:01, 32.68batch/s, loss=0.00013]
#  49%|████▉     | 54/110 [00:01<00:01, 32.92batch/s, loss=0.000546]
#  52%|█████▏    | 57/110 [00:01<00:01, 32.86batch/s, loss=0.000293]
#  55%|█████▌    | 61/110 [00:01<00:01, 32.93batch/s, loss=0.000113]
#  58%|█████▊    | 64/110 [00:01<00:01, 33.07batch/s, loss=0.000183]
#  61%|██████    | 67/110 [00:02<00:01, 32.86batch/s, loss=0.000108]
#  62%|██████▏   | 68/110 [00:02<00:01, 32.88batch/s, loss=0.00056]
#  65%|██████▍   | 71/110 [00:02<00:01, 32.95batch/s, loss=0.000365]
#  67%|██████▋   | 74/110 [00:02<00:01, 32.73batch/s, loss=6.58e-5]
#  70%|███████   | 77/110 [00:02<00:01, 32.73batch/s, loss=0.000153]
#  73%|███████▎  | 80/110 [00:02<00:00, 32.46batch/s, loss=0.000239]
#  76%|███████▋  | 84/110 [00:02<00:00, 32.50batch/s, loss=0.000544]
#  79%|███████▉  | 87/110 [00:02<00:00, 32.34batch/s, loss=0.000253]
#  81%|████████  | 89/110 [00:02<00:00, 32.18batch/s, loss=0.000393]
#  84%|████████▎ | 92/110 [00:02<00:00, 31.97batch/s, loss=0.000249]
#  87%|████████▋ | 96/110 [00:03<00:00, 32.00batch/s, loss=0.000136]
#  90%|█████████ | 99/110 [00:03<00:00, 31.91batch/s, loss=0.000254]
#  93%|█████████▎| 102/110 [00:03<00:00, 31.93batch/s, loss=0.000685]
#  95%|█████████▌| 105/110 [00:03<00:00, 31.88batch/s, loss=0.000177]
#  98%|█████████▊| 108/110 [00:03<00:00, 31.85batch/s, loss=0.000309]
# [2022-01-29 13:53:30] INFO     Finished training epoch 47, stats on rank 0: {'epoch': 47, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.000288132104117687, 'last_train_loss': 0.00022759989951737225}
#   2%|▏         | 2/110 [00:00<00:02, 37.75batch/s, loss=0.00017]
#   5%|▍         | 5/110 [00:00<00:03, 33.46batch/s, loss=0.000371]
#   8%|▊         | 9/110 [00:00<00:02, 34.75batch/s, loss=0.000139]
#  11%|█         | 12/110 [00:00<00:02, 32.79batch/s, loss=0.000287]
#  14%|█▎        | 15/110 [00:00<00:02, 33.03batch/s, loss=0.000152]
#  17%|█▋        | 19/110 [00:00<00:02, 33.74batch/s, loss=0.000213]
#  20%|██        | 22/110 [00:00<00:02, 33.33batch/s, loss=0.000235]
#  24%|██▎       | 26/110 [00:00<00:02, 33.67batch/s, loss=0.000206]
#  26%|██▋       | 29/110 [00:00<00:02, 33.04batch/s, loss=3.29e-5]
#  30%|███       | 33/110 [00:00<00:02, 33.44batch/s, loss=0.000311]
#  33%|███▎      | 36/110 [00:01<00:02, 33.62batch/s, loss=0.000278]
#  36%|███▋      | 40/110 [00:01<00:02, 33.52batch/s, loss=0.000235]
#  40%|████      | 44/110 [00:01<00:01, 33.92batch/s, loss=0.000284]
#  42%|████▏     | 46/110 [00:01<00:01, 33.19batch/s, loss=0.000161]
#  45%|████▌     | 50/110 [00:01<00:01, 33.26batch/s, loss=0.000132]
#  48%|████▊     | 53/110 [00:01<00:01, 33.17batch/s, loss=0.000274]
#  51%|█████     | 56/110 [00:01<00:01, 33.33batch/s, loss=0.000283]
#  54%|█████▎    | 59/110 [00:01<00:01, 32.84batch/s, loss=0.0003]
#  57%|█████▋    | 63/110 [00:01<00:01, 32.92batch/s, loss=0.000288]
#  60%|██████    | 66/110 [00:02<00:01, 32.74batch/s, loss=0.000114]
#  63%|██████▎   | 69/110 [00:02<00:01, 32.62batch/s, loss=0.000535]
#  65%|██████▌   | 72/110 [00:02<00:01, 32.73batch/s, loss=0.000429]
#  69%|██████▉   | 76/110 [00:02<00:01, 32.70batch/s, loss=0.000164]
#  72%|███████▏  | 79/110 [00:02<00:00, 32.60batch/s, loss=0.000161]
#  75%|███████▍  | 82/110 [00:02<00:00, 32.52batch/s, loss=0.0005]
#  78%|███████▊  | 86/110 [00:02<00:00, 32.63batch/s, loss=9.13e-5]
#  81%|████████  | 89/110 [00:02<00:00, 32.58batch/s, loss=0.000388]
#  84%|████████▎ | 92/110 [00:02<00:00, 32.61batch/s, loss=0.000247]
#  86%|████████▋ | 95/110 [00:02<00:00, 32.48batch/s, loss=0.000178]
#  90%|█████████ | 99/110 [00:03<00:00, 32.61batch/s, loss=0.000253]
#  94%|█████████▎| 103/110 [00:03<00:00, 32.71batch/s, loss=0.00013]
#  96%|█████████▋| 106/110 [00:03<00:00, 32.54batch/s, loss=0.000541]
# [2022-01-29 13:53:33] INFO     Finished training epoch 48, stats on rank 0: {'epoch': 48, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.00028741632978122937, 'last_train_loss': 0.0002250669786008075}
#   0%|          | 0/110 [00:00<?, ?batch/s]
#   2%|▏         | 2/110 [00:00<00:04, 21.99batch/s, loss=0.000172]
#   5%|▌         | 6/110 [00:00<00:03, 29.00batch/s, loss=0.000211]
#   8%|▊         | 9/110 [00:00<00:03, 29.30batch/s, loss=0.000142]
#  12%|█▏        | 13/110 [00:00<00:03, 30.97batch/s, loss=0.000218]
#  15%|█▍        | 16/110 [00:00<00:03, 31.19batch/s, loss=0.000595]
#  17%|█▋        | 19/110 [00:00<00:02, 31.18batch/s, loss=0.000213]
#  20%|██        | 22/110 [00:00<00:02, 30.75batch/s, loss=0.000237]
#  24%|██▎       | 26/110 [00:00<00:02, 31.58batch/s, loss=0.000208]
#  26%|██▋       | 29/110 [00:00<00:02, 31.55batch/s, loss=3.28e-5]
#  30%|███       | 33/110 [00:01<00:02, 31.92batch/s, loss=0.000312]
#  32%|███▏      | 35/110 [00:01<00:02, 31.20batch/s, loss=0.000297]
#  35%|███▌      | 39/110 [00:01<00:02, 31.47batch/s, loss=0.000136]
#  38%|███▊      | 42/110 [00:01<00:02, 31.26batch/s, loss=0.000151]
#  41%|████      | 45/110 [00:01<00:02, 31.21batch/s, loss=0.000319]
#  45%|████▍     | 49/110 [00:01<00:01, 31.47batch/s, loss=0.000434]
#  47%|████▋     | 52/110 [00:01<00:01, 31.41batch/s, loss=0.000791]
#  50%|█████     | 55/110 [00:01<00:01, 31.57batch/s, loss=0.00037]
#  54%|█████▎    | 59/110 [00:01<00:01, 31.71batch/s, loss=0.000301]
#  57%|█████▋    | 63/110 [00:01<00:01, 32.00batch/s, loss=0.000284]
#  60%|██████    | 66/110 [00:02<00:01, 31.95batch/s, loss=0.000112]
#  63%|██████▎   | 69/110 [00:02<00:01, 31.82batch/s, loss=0.000537]
#  65%|██████▌   | 72/110 [00:02<00:01, 31.95batch/s, loss=0.000427]
#  69%|██████▉   | 76/110 [00:02<00:01, 31.96batch/s, loss=0.000161]
#  72%|███████▏  | 79/110 [00:02<00:00, 32.04batch/s, loss=0.000159]
#  75%|███████▍  | 82/110 [00:02<00:00, 31.89batch/s, loss=0.000502]
#  78%|███████▊  | 86/110 [00:02<00:00, 32.11batch/s, loss=9.08e-5]
#  81%|████████  | 89/110 [00:02<00:00, 32.17batch/s, loss=0.000383]
#  85%|████████▍ | 93/110 [00:02<00:00, 32.21batch/s, loss=0.000181]
#  87%|████████▋ | 96/110 [00:02<00:00, 32.26batch/s, loss=0.000133]
#  91%|█████████ | 100/110 [00:03<00:00, 32.37batch/s, loss=0.000573]
#  94%|█████████▎| 103/110 [00:03<00:00, 32.32batch/s, loss=0.00013]
#  97%|█████████▋| 107/110 [00:03<00:00, 32.43batch/s, loss=0.000479]
# [2022-01-29 13:53:36] INFO     Finished training epoch 49, stats on rank 0: {'epoch': 49, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.00028674068190841744, 'last_train_loss': 0.00022275045921560377}
#   0%|          | 0/110 [00:00<?, ?batch/s]
#   4%|▎         | 4/110 [00:00<00:03, 34.80batch/s, loss=0.00027]
#   6%|▋         | 7/110 [00:00<00:02, 35.08batch/s, loss=0.000125]
#   9%|▉         | 10/110 [00:00<00:02, 33.45batch/s, loss=0.000294]
#  12%|█▏        | 13/110 [00:00<00:02, 32.47batch/s, loss=0.000221]
#  15%|█▍        | 16/110 [00:00<00:02, 31.82batch/s, loss=0.000596]
#  18%|█▊        | 20/110 [00:00<00:02, 32.86batch/s, loss=0.000156]
#  21%|██        | 23/110 [00:00<00:02, 32.12batch/s, loss=0.000124]
#  24%|██▎       | 26/110 [00:00<00:02, 32.03batch/s, loss=0.00021]
#  26%|██▋       | 29/110 [00:00<00:02, 31.42batch/s, loss=3.26e-5]
#  29%|██▉       | 32/110 [00:01<00:02, 31.66batch/s, loss=8.2e-5]
#  32%|███▏      | 35/110 [00:01<00:02, 31.47batch/s, loss=0.000299]
#  35%|███▌      | 39/110 [00:01<00:02, 31.62batch/s, loss=0.000135]
#  38%|███▊      | 42/110 [00:01<00:02, 31.80batch/s, loss=0.000154]
#  42%|████▏     | 46/110 [00:01<00:02, 31.81batch/s, loss=0.000163]
#  45%|████▍     | 49/110 [00:01<00:01, 31.77batch/s, loss=0.000434]
#  47%|████▋     | 52/110 [00:01<00:01, 31.81batch/s, loss=0.000797]
#  51%|█████     | 56/110 [00:01<00:01, 31.99batch/s, loss=0.000284]
#  53%|█████▎    | 58/110 [00:01<00:01, 31.67batch/s, loss=0.000399]
#  54%|█████▎    | 59/110 [00:01<00:01, 31.74batch/s, loss=0.000302]
#  56%|█████▋    | 62/110 [00:01<00:01, 31.90batch/s, loss=0.000116]
#  59%|█████▉    | 65/110 [00:02<00:01, 31.60batch/s, loss=0.000351]
#  62%|██████▏   | 68/110 [00:02<00:01, 31.73batch/s, loss=0.00055]
#  65%|██████▌   | 72/110 [00:02<00:01, 31.79batch/s, loss=0.000424]
#  68%|██████▊   | 75/110 [00:02<00:01, 31.76batch/s, loss=0.000157]
#  71%|███████   | 78/110 [00:02<00:01, 31.80batch/s, loss=0.000205]
#  74%|███████▎  | 81/110 [00:02<00:00, 31.71batch/s, loss=0.000359]
#  77%|███████▋  | 85/110 [00:02<00:00, 31.84batch/s, loss=0.0007]
#  80%|████████  | 88/110 [00:02<00:00, 31.84batch/s, loss=0.000625]
#  83%|████████▎ | 91/110 [00:02<00:00, 31.78batch/s, loss=0.000391]
#  85%|████████▌ | 94/110 [00:02<00:00, 31.72batch/s, loss=0.000428]
#  89%|████████▉ | 98/110 [00:03<00:00, 31.81batch/s, loss=0.000209]
#  92%|█████████▏| 101/110 [00:03<00:00, 31.90batch/s, loss=0.000574]
#  95%|█████████▍| 104/110 [00:03<00:00, 31.75batch/s, loss=0.000263]
#  98%|█████████▊| 108/110 [00:03<00:00, 31.85batch/s, loss=0.000317]
# [{'batch_count': 110,
#   'epoch': 1,
#   'last_train_loss': 0.0002149020874639973,
#   'num_samples': 1759,
#   'train_loss': 0.008658889903681447},
#  {'batch_count': 110,
#   'epoch': 2,
#   'last_train_loss': 0.00022630863531958312,
#   'num_samples': 1759,
#   'train_loss': 0.0005809495594202779},
#  {'batch_count': 110,
#   'epoch': 3,
#   'last_train_loss': 0.00026920929667539895,
#   'num_samples': 1759,
#   'train_loss': 0.0005363702827225629},
#  {'batch_count': 110,
#   'epoch': 4,
#   'last_train_loss': 0.0002626990608405322,
#   'num_samples': 1759,
#   'train_loss': 0.0004787359811674545},
#  {'batch_count': 110,
#   'epoch': 5,
#   'last_train_loss': 0.00026440073270350695,
#   'num_samples': 1759,
#   'train_loss': 0.0004394685494080249},
#  {'batch_count': 110,
#   'epoch': 6,
#   'last_train_loss': 0.00027262340881861746,
#   'num_samples': 1759,
#   'train_loss': 0.00041314900231350694},
#  {'batch_count': 110,
#   'epoch': 7,
#   'last_train_loss': 0.0002826085838023573,
#   'num_samples': 1759,
#   'train_loss': 0.00039369146180558357},
#  {'batch_count': 110,
#   'epoch': 8,
#   'last_train_loss': 0.0002910952316597104,
#   'num_samples': 1759,
#   'train_loss': 0.0003775677943457661},
#  {'batch_count': 110,
#   'epoch': 9,
#   'last_train_loss': 0.00029699920560233295,
#   'num_samples': 1759,
#   'train_loss': 0.00036317071022141267},
#  {'batch_count': 110,
#   'epoch': 10,
#   'last_train_loss': 0.000300591200357303,
#   'num_samples': 1759,
#   'train_loss': 0.0003499856414497079},
#  {'batch_count': 110,
#   'epoch': 11,
#   'last_train_loss': 0.0003024511970579624,
#   'num_samples': 1759,
#   'train_loss': 0.00033800279478197825},
#  {'batch_count': 110,
#   'epoch': 12,
#   'last_train_loss': 0.00030307142878882587,
#   'num_samples': 1759,
#   'train_loss': 0.00032745407379153985},
#  {'batch_count': 110,
#   'epoch': 13,
#   'last_train_loss': 0.0003028912760782987,
#   'num_samples': 1759,
#   'train_loss': 0.00031864822142563693},
#  {'batch_count': 110,
#   'epoch': 14,
#   'last_train_loss': 0.0003023739845957607,
#   'num_samples': 1759,
#   'train_loss': 0.00031181034697746546},
#  {'batch_count': 110,
#   'epoch': 15,
#   'last_train_loss': 0.0003019625728484243,
#   'num_samples': 1759,
#   'train_loss': 0.00030697860767005405},
#  {'batch_count': 110,
#   'epoch': 16,
#   'last_train_loss': 0.0003019674331881106,
#   'num_samples': 1759,
#   'train_loss': 0.0003039903260794992},
#  {'batch_count': 110,
#   'epoch': 17,
#   'last_train_loss': 0.00030248460825532675,
#   'num_samples': 1759,
#   'train_loss': 0.0003025179263005788},
#  {'batch_count': 110,
#   'epoch': 18,
#   'last_train_loss': 0.00030343487742356956,
#   'num_samples': 1759,
#   'train_loss': 0.00030214283277488175},
#  {'batch_count': 110,
#   'epoch': 19,
#   'last_train_loss': 0.00030470185447484255,
#   'num_samples': 1759,
#   'train_loss': 0.00030244768649734656},
#  {'batch_count': 110,
#   'epoch': 20,
#   'last_train_loss': 0.0003062051546294242,
#   'num_samples': 1759,
#   'train_loss': 0.00030308853207919014},
#  {'batch_count': 110,
#   'epoch': 21,
#   'last_train_loss': 0.0003078758018091321,
#   'num_samples': 1759,
#   'train_loss': 0.0003038118420988893},
#  {'batch_count': 110,
#   'epoch': 22,
#   'last_train_loss': 0.0003096054133493453,
#   'num_samples': 1759,
#   'train_loss': 0.000304450800481812},
#  {'batch_count': 110,
#   'epoch': 23,
#   'last_train_loss': 0.0003112044942099601,
#   'num_samples': 1759,
#   'train_loss': 0.0003049005723682525},
#  {'batch_count': 110,
#   'epoch': 24,
#   'last_train_loss': 0.00031243267585523427,
#   'num_samples': 1759,
#   'train_loss': 0.00030510318469832747},
#  {'batch_count': 110,
#   'epoch': 25,
#   'last_train_loss': 0.00031304938602261245,
#   'num_samples': 1759,
#   'train_loss': 0.0003050419749913662},
#  {'batch_count': 110,
#   'epoch': 26,
#   'last_train_loss': 0.00031288605532608926,
#   'num_samples': 1759,
#   'train_loss': 0.0003047340872069856},
#  {'batch_count': 110,
#   'epoch': 27,
#   'last_train_loss': 0.00031186186242848635,
#   'num_samples': 1759,
#   'train_loss': 0.0003042206955219091},
#  {'batch_count': 110,
#   'epoch': 28,
#   'last_train_loss': 0.0003099945024587214,
#   'num_samples': 1759,
#   'train_loss': 0.0003035578015465565},
#  {'batch_count': 110,
#   'epoch': 29,
#   'last_train_loss': 0.00030735551263205707,
#   'num_samples': 1759,
#   'train_loss': 0.0003027995386537622},
#  {'batch_count': 110,
#   'epoch': 30,
#   'last_train_loss': 0.0003040453011635691,
#   'num_samples': 1759,
#   'train_loss': 0.00030199041245746117},
#  {'batch_count': 110,
#   'epoch': 31,
#   'last_train_loss': 0.00030016631353646517,
#   'num_samples': 1759,
#   'train_loss': 0.0003011623106464307},
#  {'batch_count': 110,
#   'epoch': 32,
#   'last_train_loss': 0.0002958120603580028,
#   'num_samples': 1759,
#   'train_loss': 0.0003003346436390163},
#  {'batch_count': 110,
#   'epoch': 33,
#   'last_train_loss': 0.00029106877627782524,
#   'num_samples': 1759,
#   'train_loss': 0.00029951637680483467},
#  {'batch_count': 110,
#   'epoch': 34,
#   'last_train_loss': 0.00028601899975910783,
#   'num_samples': 1759,
#   'train_loss': 0.00029870989205828757},
#  {'batch_count': 110,
#   'epoch': 35,
#   'last_train_loss': 0.0002807426790241152,
#   'num_samples': 1759,
#   'train_loss': 0.0002979128620525872},
#  {'batch_count': 110,
#   'epoch': 36,
#   'last_train_loss': 0.00027532194508239627,
#   'num_samples': 1759,
#   'train_loss': 0.0002971188035165397},
#  {'batch_count': 110,
#   'epoch': 37,
#   'last_train_loss': 0.00026984771830029786,
#   'num_samples': 1759,
#   'train_loss': 0.00029632225742199866},
#  {'batch_count': 110,
#   'epoch': 38,
#   'last_train_loss': 0.00026440847432240844,
#   'num_samples': 1759,
#   'train_loss': 0.00029551679703431876},
#  {'batch_count': 110,
#   'epoch': 39,
#   'last_train_loss': 0.0002590955118648708,
#   'num_samples': 1759,
#   'train_loss': 0.0002946982356706966},
#  {'batch_count': 110,
#   'epoch': 40,
#   'last_train_loss': 0.00025399166042916477,
#   'num_samples': 1759,
#   'train_loss': 0.00029386607216284075},
#  {'batch_count': 110,
#   'epoch': 41,
#   'last_train_loss': 0.00024916903930716217,
#   'num_samples': 1759,
#   'train_loss': 0.0002930222450674264},
#  {'batch_count': 110,
#   'epoch': 42,
#   'last_train_loss': 0.00024468108313158154,
#   'num_samples': 1759,
#   'train_loss': 0.00029217216835874534},
#  {'batch_count': 110,
#   'epoch': 43,
#   'last_train_loss': 0.00024055888934526592,
#   'num_samples': 1759,
#   'train_loss': 0.00029132491947849815},
#  {'batch_count': 110,
#   'epoch': 44,
#   'last_train_loss': 0.00023681489983573556,
#   'num_samples': 1759,
#   'train_loss': 0.00029048883632665175},
#  {'batch_count': 110,
#   'epoch': 45,
#   'last_train_loss': 0.0002334338496439159,
#   'num_samples': 1759,
#   'train_loss': 0.00028967355411592925},
#  {'batch_count': 110,
#   'epoch': 46,
#   'last_train_loss': 0.00023037665232550353,
#   'num_samples': 1759,
#   'train_loss': 0.0002888858812399057},
#  {'batch_count': 110,
#   'epoch': 47,
#   'last_train_loss': 0.00022759989951737225,
#   'num_samples': 1759,
#   'train_loss': 0.000288132104117687},
#  {'batch_count': 110,
#   'epoch': 48,
#   'last_train_loss': 0.0002250669786008075,
#   'num_samples': 1759,
#   'train_loss': 0.00028741632978122937},
#  {'batch_count': 110,
#   'epoch': 49,
#   'last_train_loss': 0.00022275045921560377,
#   'num_samples': 1759,
#   'train_loss': 0.00028674068190841744},
#  {'batch_count': 110,
#   'epoch': 50,
#   'last_train_loss': 0.00022063068172428757,
#   'num_samples': 1759,
#   'train_loss': 0.0002861050031085818}]

# %%
forecaster.to_local()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py:65: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# [2022-01-29 13:53:40] INFO     Finished training epoch 50, stats on rank 0: {'epoch': 50, 'batch_count': 110, 'num_samples': 1759, 'train_loss': 0.0002861050031085818, 'last_train_loss': 0.00022063068172428757}

# %%
# make prediction
y_pred = forecaster.predict(X_test)

# %%
y_pred_unscale = tsdata_test.unscale_numpy(y_pred)
y_test_unscale = tsdata_test.unscale_numpy(y_test)

# %%
from bigdl.orca.automl.metrics import Evaluator
print("RMSE is", Evaluator.evaluate("rmse", y_test_unscale, y_pred_unscale, multioutput='uniform_average'))
print("MAPE is", Evaluator.evaluate("mape", y_test_unscale, y_pred_unscale, multioutput='uniform_average'))
# Out:
# RMSE is 2.453263886822678
# MAPE is 1.5455114484220995

# %%
# Plot predictions
plt.figure(figsize=(10,5))
plt.plot(tsdata_test.df.date[50:], y_test_unscale[:, :, 0], color='blue', label="VCB daily price Raw")
plt.plot(tsdata_test.df.date[50:], y_pred_unscale[:, :, 0], color='red', label="VCB daily price Predicted")
plt.xlabel("Time Period")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
