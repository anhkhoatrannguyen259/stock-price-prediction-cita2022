# %% [markdown]
# ## **Install BigDL Chronos**

# %%
# Install latest pre-release version of bigdl-chronos 
# Installing bigdl-chronos from pip will automatically install pyspark, bigdl, and their dependencies.
# !pip install --pre --upgrade bigdl-chronos[all]
# !pip uninstall -y torchtext
exit() # restart the runtime to refresh installed pkg
# Out:
# Collecting bigdl-chronos[all]
#   Downloading bigdl_chronos-0.14.0b20220129-py3-none-manylinux1_x86_64.whl (222 kB)
#      |████████████████████████████████| 222 kB 4.9 MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from bigdl-chronos[all]) (1.0.2)
# Requirement already satisfied: pandas<1.3.0,>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from bigdl-chronos[all]) (1.1.5)
# Collecting bigdl-nano[pytorch]
#   Downloading bigdl_nano-0.14.0b20220129-py3-none-manylinux2010_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 49.8 MB/s
# Collecting bigdl-orca==0.14.0b20220129
#   Downloading bigdl_orca-0.14.0b20220129-py3-none-manylinux1_x86_64.whl (23.6 MB)
#      |████████████████████████████████| 23.6 MB 1.2 MB/s
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from bigdl-chronos[all]) (0.10.2)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.7/dist-packages (from bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (22.3.0)
# Collecting bigdl-dllib==0.14.0b20220129
#   Downloading bigdl_dllib-0.14.0b20220129-py3-none-manylinux1_x86_64.whl (100.7 MB)
#      |████████████████████████████████| 100.7 MB 58 kB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (3.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (21.3)
# Collecting conda-pack==0.3.1
#   Downloading conda_pack-0.3.1-py2.py3-none-any.whl (27 kB)
# Collecting bigdl-tf==0.14.0.dev1
#   Downloading bigdl_tf-0.14.0.dev1-py3-none-manylinux2010_x86_64.whl (71.0 MB)
#      |████████████████████████████████| 71.0 MB 372 bytes/s
# Collecting bigdl-math==0.14.0.dev1
#   Downloading bigdl_math-0.14.0.dev1-py3-none-manylinux2010_x86_64.whl (35.4 MB)
#      |████████████████████████████████| 35.4 MB 443 kB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from bigdl-dllib==0.14.0b20220129->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (1.15.0)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.7/dist-packages (from bigdl-dllib==0.14.0b20220129->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (1.19.5)
# Collecting pyspark==2.4.6
#   Downloading pyspark-2.4.6.tar.gz (218.4 MB)
#      |████████████████████████████████| 218.4 MB 51 kB/s
# Collecting async-timeout==4.0.1
#   Downloading async_timeout-4.0.1-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (2.7.0)
# Collecting hiredis==2.0.0
#   Downloading hiredis-2.0.0-cp37-cp37m-manylinux2010_x86_64.whl (85 kB)
#      |████████████████████████████████| 85 kB 3.2 MB/s
# Collecting ray[default]==1.9.0
#   Downloading ray-1.9.0-cp37-cp37m-manylinux2014_x86_64.whl (57.6 MB)
#      |████████████████████████████████| 57.6 MB 1.1 MB/s
# Collecting aioredis==1.3.1
#   Downloading aioredis-1.3.1-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 2.7 MB/s
# Collecting aiohttp==3.8.1
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 54.3 MB/s
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (5.4.8)
# Collecting setproctitle
#   Downloading setproctitle-1.2.2-cp37-cp37m-manylinux1_x86_64.whl (36 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 69.8 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.8.1->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (2.0.10)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.8.1->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (21.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.8.1->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (3.10.0.2)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 62.9 MB/s
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.1 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from conda-pack==0.3.1->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (57.4.0)
# Collecting py4j==0.10.7
#   Downloading py4j-0.10.7-py2.py3-none-any.whl (197 kB)
#      |████████████████████████████████| 197 kB 61.0 MB/s
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (1.0.3)
# Requirement already satisfied: protobuf>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (3.17.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (3.13)
# Collecting redis>=3.5.0
#   Downloading redis-4.1.2-py3-none-any.whl (173 kB)
#      |████████████████████████████████| 173 kB 58.1 MB/s
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (1.43.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (7.1.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (4.3.3)
# Collecting gpustat>=1.0.0b1
#   Downloading gpustat-1.0.0b1.tar.gz (82 kB)
#      |████████████████████████████████| 82 kB 209 kB/s
# Collecting py-spy>=0.2.0
#   Downloading py_spy-0.4.0.dev1-py2.py3-none-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 40.0 MB/s
# Collecting opencensus
#   Downloading opencensus-0.8.0-py2.py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 50.5 MB/s
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (0.13.0)
# Requirement already satisfied: smart-open in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (5.2.1)
# Collecting aiohttp-cors
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting colorful
#   Downloading colorful-0.6.0a1-py2.py3-none-any.whl (202 kB)
#      |████████████████████████████████| 202 kB 46.7 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (2.23.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (0.8.9)
# Collecting tensorboardX>=1.9
#   Downloading tensorboardX-2.4.1-py2.py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 52.2 MB/s
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.7/dist-packages (from gpustat>=1.0.0b1->ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (7.352.0)
# Collecting blessed>=1.17.1
#   Downloading blessed-1.19.1-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 4.0 MB/s
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.7/dist-packages (from blessed>=1.17.1->gpustat>=1.0.0b1->ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (0.2.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas<1.3.0,>=1.0.5->bigdl-chronos[all]) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<1.3.0,>=1.0.5->bigdl-chronos[all]) (2.8.2)
# Collecting deprecated>=1.2.3
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: importlib-metadata>=1.0 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.0->ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (4.10.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated>=1.2.3->redis>=3.5.0->ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (1.13.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.0->redis>=3.5.0->ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (3.0.7)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp==3.8.1->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (2.10)
# Requirement already satisfied: intel-openmp in /usr/local/lib/python3.7/dist-packages (from bigdl-nano[pytorch]->bigdl-chronos[all]) (2022.0.2)
# Collecting PyTurboJPEG
#   Downloading PyTurboJPEG-1.6.5.tar.gz (11 kB)
# Collecting onnxruntime
#   Downloading onnxruntime-1.10.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 34.9 MB/s
# Collecting torchvision==0.10.0
#   Downloading torchvision-0.10.0-cp37-cp37m-manylinux1_x86_64.whl (22.1 MB)
#      |████████████████████████████████| 22.1 MB 69.8 MB/s
# Collecting torch==1.9.0
#   Downloading torch-1.9.0-cp37-cp37m-manylinux1_x86_64.whl (831.4 MB)
#      |████████████████████████████████| 831.4 MB 2.4 kB/s
# Collecting onnx
#   Downloading onnx-1.10.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (12.7 MB)
#      |████████████████████████████████| 12.7 MB 47.0 MB/s
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.5.5.62-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.7 MB)
#      |████████████████████████████████| 47.7 MB 2.3 MB/s
# Collecting opencv-transforms
#   Downloading opencv_transforms-0.0.6-py3-none-any.whl (18 kB)
# Collecting pytorch-lightning==1.4.2
#   Downloading pytorch_lightning-1.4.2-py3-none-any.whl (916 kB)
#      |████████████████████████████████| 916 kB 58.0 MB/s
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 50.0 MB/s
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.1.0-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 36.0 MB/s
# Collecting torchmetrics>=0.4.0
#   Downloading torchmetrics-0.7.0-py3-none-any.whl (396 kB)
#      |████████████████████████████████| 396 kB 48.7 MB/s
# Collecting pyDeprecate==0.3.1
#   Downloading pyDeprecate-0.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning==1.4.2->bigdl-nano[pytorch]->bigdl-chronos[all]) (4.62.3)
# Collecting future>=0.17.1
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 49.4 MB/s
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.10.0->bigdl-nano[pytorch]->bigdl-chronos[all]) (7.1.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (3.3.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (0.37.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (1.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (1.0.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (3.1.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (5.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (0.18.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.7/dist-packages (from onnxruntime->bigdl-nano[pytorch]->bigdl-chronos[all]) (2.0)
# Collecting opencensus-context==0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from opencensus->ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (1.26.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]==1.9.0->bigdl-orca==0.14.0b20220129->bigdl-chronos[all]) (1.54.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->bigdl-chronos[all]) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->bigdl-chronos[all]) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->bigdl-chronos[all]) (3.0.0)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels->bigdl-chronos[all]) (0.5.2)
# Building wheels for collected packages: pyspark, gpustat, future, PyTurboJPEG
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-2.4.6-py2.py3-none-any.whl size=218814407 sha256=2feb9dcc3b667f5c0289e5c3ffec1db51bccd473ff92884a6c23afd2b2895976
#   Stored in directory: /root/.cache/pip/wheels/f1/42/b0/ba397759613f4feb1611021a2503e60e344e546671b2ae04f8
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-1.0.0b1-py3-none-any.whl size=15979 sha256=28954195a7cd9277773af9a70864cc037b8fb5bb8d195b9c9eef7597e95d2ba7
#   Stored in directory: /root/.cache/pip/wheels/1a/16/e2/3e2437fba4c4b6a97a97bd96fce5d14e66cff5c4966fb1cc8c
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=53613a510a6c28f375270453aa88a664d31fe48a204fcff7317f44eb3cdc275f
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for PyTurboJPEG (setup.py) ... done
#   Created wheel for PyTurboJPEG: filename=PyTurboJPEG-1.6.5-py3-none-any.whl size=12160 sha256=8cb27973b040d5244141e323732fa6884ed0d31d2ac1fba6cf041e2455093f2e
#   Stored in directory: /root/.cache/pip/wheels/1b/6a/97/17286b24cd97dda462b5a886107f8663f1ccc7705f148b3850
# Successfully built pyspark gpustat future PyTurboJPEG
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, torch, pyDeprecate, py4j, fsspec, deprecated, aiohttp, torchmetrics, redis, pyyaml, pyspark, opencensus-context, hiredis, future, blessed, torchvision, tensorboardX, ray, PyTurboJPEG, pytorch-lightning, py-spy, opencv-transforms, opencv-python-headless, opencensus, onnxruntime, onnx, gpustat, conda-pack, colorful, bigdl-tf, bigdl-nano, bigdl-math, bigdl-dllib, aioredis, aiohttp-cors, setproctitle, bigdl-orca, bigdl-chronos
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.11.1+cu111
#     Uninstalling torchvision-0.11.1+cu111:
#       Successfully uninstalled torchvision-0.11.1+cu111
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.9.0 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.9.0 which is incompatible.
# Successfully installed PyTurboJPEG-1.6.5 aiohttp-3.8.1 aiohttp-cors-0.7.0 aioredis-1.3.1 aiosignal-1.2.0 async-timeout-4.0.1 asynctest-0.13.0 bigdl-chronos-0.14.0b20220129 bigdl-dllib-0.14.0b20220129 bigdl-math-0.14.0.dev1 bigdl-nano-0.14.0b20220129 bigdl-orca-0.14.0b20220129 bigdl-tf-0.14.0.dev1 blessed-1.19.1 colorful-0.6.0a1 conda-pack-0.3.1 deprecated-1.2.13 frozenlist-1.3.0 fsspec-2022.1.0 future-0.18.2 gpustat-1.0.0b1 hiredis-2.0.0 multidict-6.0.2 onnx-1.10.2 onnxruntime-1.10.0 opencensus-0.8.0 opencensus-context-0.1.2 opencv-python-headless-4.5.5.62 opencv-transforms-0.0.6 py-spy-0.4.0.dev1 py4j-0.10.7 pyDeprecate-0.3.1 pyspark-2.4.6 pytorch-lightning-1.4.2 pyyaml-6.0 ray-1.9.0 redis-4.1.2 setproctitle-1.2.2 tensorboardX-2.4.1 torch-1.9.0 torchmetrics-0.7.0 torchvision-0.10.0 yarl-1.7.2
# Found existing installation: torchtext 0.11.0
# Uninstalling torchtext-0.11.0:
#   Successfully uninstalled torchtext-0.11.0

# %% [markdown]
# ## **Import data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
f = open('/content/drive/MyDrive/Courses/DS104_Distributed-And-Parallel-Computing/Đồ-án-DS104/dataset/stock_prices.json')
 
# returns JSON object as
# a dictionary
data = json.load(f)
 
# Iterating through the json
# list
with open('data.json', 'w') as f:
    json.dump(data['data'], f)

# %%
df = pd.read_json('data.json')
df
# Out:
#      code       date      time floor  ...      ptValue  change  adChange  pctChange
# 0     VCB 2022-01-20  15:01:03  HOSE  ...            0     0.3    0.3000     0.3456
# 1     VCB 2022-01-19  15:01:02  HOSE  ...  41500000000    -0.8   -0.8000    -0.9132
# 2     VCB 2022-01-18  15:01:03  HOSE  ...   3412500000     1.4    1.4000     1.6241
# 3     VCB 2022-01-17  15:01:03  HOSE  ...   3476541000     2.8    2.8000     3.3573
# 4     VCB 2022-01-14  15:01:03  HOSE  ...   2307000000     1.5    1.5000     1.8315
# ...   ...        ...       ...   ...  ...          ...     ...       ...        ...
# 2254  VCB 2013-01-08  14:01:05  HOSE  ...            0     1.5    0.6310     5.0000
# 2255  VCB 2013-01-07  14:01:04  HOSE  ...            0     0.8    0.3365     2.7397
# 2256  VCB 2013-01-04  14:01:07  HOSE  ...            0     0.7    0.2945     2.4561
# 2257  VCB 2013-01-03  14:01:06  HOSE  ...            0     0.7    0.2945     2.5180
# 2258  VCB 2013-01-02  14:01:04  HOSE  ...            0     0.6    0.2524     2.2059
#
# [2259 rows x 25 columns]

# %%
df = df.sort_values(by="date", ignore_index=True)
df
# Out:
#      code       date      time floor  ...      ptValue  change  adChange  pctChange
# 0     VCB 2013-01-02  14:01:04  HOSE  ...            0     0.6    0.2524     2.2059
# 1     VCB 2013-01-03  14:01:06  HOSE  ...            0     0.7    0.2945     2.5180
# 2     VCB 2013-01-04  14:01:07  HOSE  ...            0     0.7    0.2945     2.4561
# 3     VCB 2013-01-07  14:01:04  HOSE  ...            0     0.8    0.3365     2.7397
# 4     VCB 2013-01-08  14:01:05  HOSE  ...            0     1.5    0.6310     5.0000
# ...   ...        ...       ...   ...  ...          ...     ...       ...        ...
# 2254  VCB 2022-01-14  15:01:03  HOSE  ...   2307000000     1.5    1.5000     1.8315
# 2255  VCB 2022-01-17  15:01:03  HOSE  ...   3476541000     2.8    2.8000     3.3573
# 2256  VCB 2022-01-18  15:01:03  HOSE  ...   3412500000     1.4    1.4000     1.6241
# 2257  VCB 2022-01-19  15:01:02  HOSE  ...  41500000000    -0.8   -0.8000    -0.9132
# 2258  VCB 2022-01-20  15:01:03  HOSE  ...            0     0.3    0.3000     0.3456
#
# [2259 rows x 25 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10, 5))
plt.plot(df.date, df.close, color='blue', label='VCB daily price Raw')
plt.xlabel("Time Period")
plt.ylabel("Stock Price")
plt.legend()
plt.show()

# %% [markdown]
# ## **Predict with Chronos AutoTS**

# %% [markdown]
# ### **Step 1: Init Orca Context**

# %%
# import necesary libraries and modules
from bigdl.orca import init_orca_context, stop_orca_context
from bigdl.orca import OrcaContext

# %% [markdown]
# This is the only place where you need to specify local or distributed mode. View [Orca Context](https://analytics-zoo.readthedocs.io/en/latest/doc/Orca/Overview/orca-context.html) for more details. Note that argument ```init_ray_on_spark``` must be ```True``` for Chronos.

# %%
# recommended to set it to True when running bigdl-chronos in Jupyter notebook 
OrcaContext.log_output = True # (this will display terminal's stdout and stderr in the Jupyter notebook).

init_orca_context(cluster_mode="local", cores=4, init_ray_on_spark=True) # run in local mode

#init_orca_context(cluster_mode="k8s", master="k8s://https://<k8s-apiserver-host>:<k8s-apiserver-port>", container_image="intelanalytics/bigdl-k8s:latest", num_nodes=2, cores=2, init_ray_on_spark=True, conda_name='Anaconda3-5.1.0-Linux-x86_64') # run on K8s cluster

#init_orca_context(cluster_mode="yarn-client", num_nodes=2, cores=2, init_ray_on_spark=True) # run on Hadoop YARN cluster
# Out:
# Initializing orca context
# Current pyspark location is : /usr/local/lib/python3.7/dist-packages/pyspark/__init__.py
# Start to getOrCreate SparkContext
# pyspark_submit_args is:  --driver-class-path /usr/local/lib/python3.7/dist-packages/bigdl/share/dllib/lib/bigdl-dllib-spark_2.4.6-0.14.0-SNAPSHOT-jar-with-dependencies.jar:/usr/local/lib/python3.7/dist-packages/bigdl/share/orca/lib/bigdl-orca-spark_2.4.6-0.14.0-SNAPSHOT-jar-with-dependencies.jar pyspark-shell
# 2022-01-29 16:26:25 WARN  NativeCodeLoader:62 - Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/usr/local/lib/python3.7/dist-packages/pyspark/jars/spark-unsafe_2.11-2.4.6.jar) to method java.nio.Bits.unaligned()
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# 2022-01-29 16:26:28,408 Thread-3 WARN The bufferSize is set to 4000 but bufferedIo is false: false
# 2022-01-29 16:26:28,412 Thread-3 WARN The bufferSize is set to 4000 but bufferedIo is false: false
# 2022-01-29 16:26:28,413 Thread-3 WARN The bufferSize is set to 4000 but bufferedIo is false: false
# 2022-01-29 16:26:28,414 Thread-3 WARN The bufferSize is set to 4000 but bufferedIo is false: false
# 22-01-29 16:26:28 [Thread-3] INFO  Engine$:121 - Auto detect executor number and executor cores number
# 22-01-29 16:26:28 [Thread-3] INFO  Engine$:123 - Executor number is 1 and executor cores number is 4
# User settings:
#
#    KMP_AFFINITY=granularity=fine,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_SETTINGS=1
#    OMP_NUM_THREADS=1
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_HAND_THREAD=false
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=false
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_FORKJOIN_FRAMES=true
#    KMP_FORKJOIN_FRAMES_MODE=3
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_ITT_PREPARE_DELAY=0
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_MWAIT_HINTS=0
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=2
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USER_LEVEL_MWAIT=false
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=true
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEBUG=disabled
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=2147483647
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED=false
#    OMP_NUM_THREADS='1'
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_TOOL=enabled
#    OMP_TOOL_LIBRARIES: value is not defined
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='noverbose,warnings,respect,granularity=fine,compact,1,0'
# 22-01-29 16:26:29 [Thread-3] INFO  ThreadPool$:95 - Set mkl threads to 1 on thread 16
# 2022-01-29 16:26:29 WARN  SparkContext:66 - Using an existing SparkContext; some configuration may not take effect.
# 22-01-29 16:26:29 [Thread-3] INFO  Engine$:446 - Find existing spark context. Checking the spark conf...
# Successfully got a SparkContext
# cls.getname: com.intel.analytics.bigdl.dllib.utils.python.api.Sample
# BigDLBasePickler registering: bigdl.dllib.utils.common  Sample
# cls.getname: com.intel.analytics.bigdl.dllib.utils.python.api.EvaluatedResult
# BigDLBasePickler registering: bigdl.dllib.utils.common  EvaluatedResult
# cls.getname: com.intel.analytics.bigdl.dllib.utils.python.api.JTensor
# BigDLBasePickler registering: bigdl.dllib.utils.common  JTensor
# cls.getname: com.intel.analytics.bigdl.dllib.utils.python.api.JActivity
# BigDLBasePickler registering: bigdl.dllib.utils.common  JActivity
# 2022-01-29 16:26:33,377	INFO services.py:1340 -- View the Ray dashboard at http://172.28.0.2:8265
# {'node_ip_address': '172.28.0.2', 'raylet_ip_address': '172.28.0.2', 'redis_address': '172.28.0.2:6379', 'object_store_address': '/tmp/ray/session_2022-01-29_16-26-30_184766_413/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2022-01-29_16-26-30_184766_413/sockets/raylet', 'webui_url': '172.28.0.2:8265', 'session_dir': '/tmp/ray/session_2022-01-29_16-26-30_184766_413', 'metrics_export_port': 62815, 'node_id': 'a965f6faac480792c2e84ad996a3b12e9d8d655b9d33059b3b331287'}
# <SparkContext master=local[4] appName=pyspark-shell>

# %% [markdown]
# ### **Step 2: Data transformation and feature engineering using Chronos TSDataset**
# [TSDataset](https://bigdl.readthedocs.io/en/latest/doc/PythonAPI/Chronos/tsdataset.html) is our abstract of time series dataset for data transformation and feature engineering. Here we use it to preprocess the data.

# %%
from bigdl.chronos.data import TSDataset
from sklearn.preprocessing import StandardScaler

tsdata_train, tsdata_val, tsdata_test = TSDataset.from_pandas(df, # the dataframe to load
                                                              dt_col="date",  # the column name specifying datetime
                                                              target_col="close", # the column name to predict
                                                              with_split=True, # split the dataset into 3 parts
                                                              val_ratio=0.1, # validation set ratio
                                                              test_ratio=0.1) # test set ratio

# for each tsdataset, we 
# 1. generate datetime feature columns.
# 2. impute the dataset with last occured value.
# 3. scale the dataset with standard scaler, fit = true for train data.
standard_scaler = StandardScaler()
for tsdata in [tsdata_train, tsdata_val, tsdata_test]:
    # tsdata.gen_dt_feature()\
    #       .impute(mode="last")\
    #       .scale(standard_scaler, fit=(tsdata is tsdata_train))
    tsdata.impute(mode="last")\
          .scale(standard_scaler, fit=(tsdata is tsdata_train))

    #tsdata.scale(standard_scaler, fit=(tsdata is tsdata_train))
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### **Step 3: Create an AutoTSEstimator**

# %% [markdown]
# [AutoTSEstimator](https://bigdl.readthedocs.io/en/latest/doc/PythonAPI/Chronos/autotsestimator.html) is our Automated TimeSeries Estimator for time series forecasting task.

# %%
from bigdl.chronos.autots import AutoTSEstimator
auto_estimator = AutoTSEstimator(model='seq2seq', # the model name used for training
                                 search_space='normal', # a default hyper parameter search space
                                 past_seq_len=50, future_seq_len=1, # hp sampling function of past_seq_len for auto-tuning
                                 selected_features='auto')

# %% [markdown]
# ### **Step 4: Fit with AutoTSEstimator**

# %%
# fit with AutoTSEstimator for a returned TSPipeline
import bigdl.orca.automl.hp as hp
ts_pipeline = auto_estimator.fit(data=tsdata_train, # train dataset
                                 validation_data=tsdata_val, # validation dataset
                                 batch_size=hp.choice([16,32,64]),
                                 epochs=50) # number of epochs to train in each trial
# Out:
# 2022-01-29 16:32:11,459	WARNING function_runner.py:562 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# == Status ==<br>Current time: 2022-01-29 16:32:16 (running for 00:00:04.98)<br>Memory usage on this node: 2.4/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/4 CPUs, 0/0 GPUs, 0.0/6.75 GiB heap, 0.0/3.37 GiB objects<br>Result logdir: /tmp/autots_estimator/autots_estimator<br>Number of trials: 12/12 (11 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status  </th><th>loc           </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  dropout</th><th style="text-align: right;">        lr</th><th style="text-align: right;">  lstm_hidden_dim</th><th style="text-align: right;">  lstm_layer_num</th><th>teacher_forcing  </th></tr>
# </thead>
# <tbody>
# <tr><td>train_func_025f7_00000</td><td>RUNNING </td><td>172.28.0.2:694</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.0544245</td><td style="text-align: right;">0.00112749</td><td style="text-align: right;">               16</td><td style="text-align: right;">               1</td><td>True             </td></tr>
# <tr><td>train_func_025f7_00001</td><td>PENDING </td><td>              </td><td style="text-align: right;">          64</td><td style="text-align: right;">0.159865 </td><td style="text-align: right;">0.00148101</td><td style="text-align: right;">               32</td><td style="text-align: right;">               1</td><td>True             </td></tr>
# <tr><td>train_func_025f7_00002</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.245262 </td><td style="text-align: right;">0.00105112</td><td style="text-align: right;">               64</td><td style="text-align: right;">               1</td><td>True             </td></tr>
# <tr><td>train_func_025f7_00003</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.214    </td><td style="text-align: right;">0.00139245</td><td style="text-align: right;">               16</td><td style="text-align: right;">               2</td><td>True             </td></tr>
# <tr><td>train_func_025f7_00004</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.283837 </td><td style="text-align: right;">0.00163116</td><td style="text-align: right;">               32</td><td style="text-align: right;">               2</td><td>True             </td></tr>
# <tr><td>train_func_025f7_00005</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.120595 </td><td style="text-align: right;">0.00414444</td><td style="text-align: right;">               64</td><td style="text-align: right;">               2</td><td>True             </td></tr>
# <tr><td>train_func_025f7_00006</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.104646 </td><td style="text-align: right;">0.00171333</td><td style="text-align: right;">               16</td><td style="text-align: right;">               1</td><td>False            </td></tr>
# <tr><td>train_func_025f7_00007</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.228704 </td><td style="text-align: right;">0.00115328</td><td style="text-align: right;">               32</td><td style="text-align: right;">               1</td><td>False            </td></tr>
# <tr><td>train_func_025f7_00008</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.290679 </td><td style="text-align: right;">0.00324824</td><td style="text-align: right;">               64</td><td style="text-align: right;">               1</td><td>False            </td></tr>
# <tr><td>train_func_025f7_00009</td><td>PENDING </td><td>              </td><td style="text-align: right;">          64</td><td style="text-align: right;">0.107087 </td><td style="text-align: right;">0.00469466</td><td style="text-align: right;">               16</td><td style="text-align: right;">               2</td><td>False            </td></tr>
# <tr><td>train_func_025f7_00010</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.0159359</td><td style="text-align: right;">0.00323255</td><td style="text-align: right;">               32</td><td style="text-align: right;">               2</td><td>False            </td></tr>
# <tr><td>train_func_025f7_00011</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.083808 </td><td style="text-align: right;">0.00105137</td><td style="text-align: right;">               64</td><td style="text-align: right;">               2</td><td>False            </td></tr>
# </tbody>
# </table><br><br>
# (ImplicitFunc pid=694) /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
# (ImplicitFunc pid=694)   import pandas.util.testing as tm
# (ImplicitFunc pid=694) /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py:65: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.05442452892887036 and num_layers=1
# (ImplicitFunc pid=694)   "num_layers={}".format(dropout, num_layers))
# (ImplicitFunc pid=695) /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
# (ImplicitFunc pid=695)   import pandas.util.testing as tm
# (ImplicitFunc pid=695) /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py:65: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.15986455572025818 and num_layers=1
# (ImplicitFunc pid=695)   "num_layers={}".format(dropout, num_layers))
# (ImplicitFunc pid=821) /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
# (ImplicitFunc pid=821)   import pandas.util.testing as tm
# == Status ==<br>Current time: 2022-01-29 16:32:28 (running for 00:00:17.00)<br>Memory usage on this node: 3.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 4.0/4 CPUs, 0/0 GPUs, 0.0/6.75 GiB heap, 0.0/3.37 GiB objects<br>Result logdir: /tmp/autots_estimator/autots_estimator<br>Number of trials: 12/12 (8 PENDING, 4 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status  </th><th>loc           </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  dropout</th><th style="text-align: right;">        lr</th><th style="text-align: right;">  lstm_hidden_dim</th><th style="text-align: right;">  lstm_layer_num</th><th>teacher_forcing  </th></tr>
# </thead>
# <tbody>
# <tr><td>train_func_025f7_00000</td><td>RUNNING </td><td>172.28.0.2:694</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.0544245</td><td style="text-align: right;">0.00112749</td><td style="text-align: right;">               16</td><td style="text-align: right;">               1</td><td>True             </td></tr>
# <tr><td>train_func_025f7_00001</td><td>RUNNING </td><td>172.28.0.2:695</td><td style="text-align: right;">          64</td><td style="text-align: right;">0.159865 </td><td style="text-align: right;">0.00148101</td><td style="text-align: right;">               32</td><td style="text-align: right;">               1</td><td>True             </td></tr>
# <tr><td>train_func_025f7_00002</td><td>RUNNING </td><td>172.28.0.2:819</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.245262 </td><td style="text-align: right;">0.00105112</td><td style="text-align: right;">               64</td><td style="text-align: right;">               1</td><td>True             </td></tr>
# <tr><td>train_func_025f7_00003</td><td>RUNNING </td><td>172.28.0.2:821</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.214    </td><td style="text-align: right;">0.00139245</td><td style="text-align: right;">               16</td><td style="text-align: right;">               2</td><td>True             </td></tr>
# <tr><td>train_func_025f7_00004</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.283837 </td><td style="text-align: right;">0.00163116</td><td style="text-align: right;">               32</td><td style="text-align: right;">               2</td><td>True             </td></tr>
# <tr><td>train_func_025f7_00005</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.120595 </td><td style="text-align: right;">0.00414444</td><td style="text-align: right;">               64</td><td style="text-align: right;">               2</td><td>True             </td></tr>
# <tr><td>train_func_025f7_00006</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.104646 </td><td style="text-align: right;">0.00171333</td><td style="text-align: right;">               16</td><td style="text-align: right;">               1</td><td>False            </td></tr>
# <tr><td>train_func_025f7_00007</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.228704 </td><td style="text-align: right;">0.00115328</td><td style="text-align: right;">               32</td><td style="text-align: right;">               1</td><td>False            </td></tr>
# <tr><td>train_func_025f7_00008</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.290679 </td><td style="text-align: right;">0.00324824</td><td style="text-align: right;">               64</td><td style="text-align: right;">               1</td><td>False            </td></tr>
# <tr><td>train_func_025f7_00009</td><td>PENDING </td><td>              </td><td style="text-align: right;">          64</td><td style="text-align: right;">0.107087 </td><td style="text-align: right;">0.00469466</td><td style="text-align: right;">               16</td><td style="text-align: right;">               2</td><td>False            </td></tr>
# <tr><td>train_func_025f7_00010</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.0159359</td><td style="text-align: right;">0.00323255</td><td style="text-align: right;">               32</td><td style="text-align: right;">               2</td><td>False            </td></tr>
# <tr><td>train_func_025f7_00011</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.083808 </td><td style="text-align: right;">0.00105137</td><td style="text-align: right;">               64</td><td style="text-align: right;">               2</td><td>False            </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-01-29 16:32:29 (running for 00:00:17.12)<br>Memory usage on this node: 3.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 4.0/4 CPUs, 0/0 GPUs, 0.0/6.75 GiB heap, 0.0/3.37 GiB objects<br>Current best trial: 025f7_00000 with mse=0.7617445676142129 and parameters={'input_feature_num': None, 'output_feature_num': 1, 'past_seq_len': 50, 'future_seq_len': 1, 'lstm_hidden_dim': 16, 'lstm_layer_num': 1, 'lr': 0.001127486929663181, 'dropout': 0.05442452892887036, 'teacher_forcing': True, 'selected_features': [], 'batch_size': 16}<br>Result logdir: /tmp/autots_estimator/autots_estimator<br>Number of trials: 12/12 (8 PENDING, 4 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status  </th><th>loc           </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  dropout</th><th style="text-align: right;">        lr</th><th style="text-align: right;">  lstm_hidden_dim</th><th style="text-align: right;">  lstm_layer_num</th><th>teacher_forcing  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  best_mse</th><th style="text-align: right;">     mse</th></tr>
# </thead>
# <tbody>
# <tr><td>train_func_025f7_00000</td><td>RUNNING </td><td>172.28.0.2:694</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.0544245</td><td style="text-align: right;">0.00112749</td><td style="text-align: right;">               16</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">     1</td><td style="text-align: right;">         8.43483</td><td style="text-align: right;">  0.761745</td><td style="text-align: right;">0.761745</td></tr>
# <tr><td>train_func_025f7_00001</td><td>RUNNING </td><td>172.28.0.2:695</td><td style="text-align: right;">          64</td><td style="text-align: right;">0.159865 </td><td style="text-align: right;">0.00148101</td><td style="text-align: right;">               32</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00002</td><td>RUNNING </td><td>172.28.0.2:819</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.245262 </td><td style="text-align: right;">0.00105112</td><td style="text-align: right;">               64</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00003</td><td>RUNNING </td><td>172.28.0.2:821</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.214    </td><td style="text-align: right;">0.00139245</td><td style="text-align: right;">               16</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00004</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.283837 </td><td style="text-align: right;">0.00163116</td><td style="text-align: right;">               32</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00005</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.120595 </td><td style="text-align: right;">0.00414444</td><td style="text-align: right;">               64</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00006</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.104646 </td><td style="text-align: right;">0.00171333</td><td style="text-align: right;">               16</td><td style="text-align: right;">               1</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00007</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.228704 </td><td style="text-align: right;">0.00115328</td><td style="text-align: right;">               32</td><td style="text-align: right;">               1</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00008</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.290679 </td><td style="text-align: right;">0.00324824</td><td style="text-align: right;">               64</td><td style="text-align: right;">               1</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00009</td><td>PENDING </td><td>              </td><td style="text-align: right;">          64</td><td style="text-align: right;">0.107087 </td><td style="text-align: right;">0.00469466</td><td style="text-align: right;">               16</td><td style="text-align: right;">               2</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00010</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.0159359</td><td style="text-align: right;">0.00323255</td><td style="text-align: right;">               32</td><td style="text-align: right;">               2</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00011</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.083808 </td><td style="text-align: right;">0.00105137</td><td style="text-align: right;">               64</td><td style="text-align: right;">               2</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# </tbody>
# </table><br><br>
# (ImplicitFunc pid=819) /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
# (ImplicitFunc pid=819)   import pandas.util.testing as tm
# (ImplicitFunc pid=819) /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py:65: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.24526223963667237 and num_layers=1
# (ImplicitFunc pid=819)   "num_layers={}".format(dropout, num_layers))
# == Status ==<br>Current time: 2022-01-29 16:32:34 (running for 00:00:22.25)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 4.0/4 CPUs, 0/0 GPUs, 0.0/6.75 GiB heap, 0.0/3.37 GiB objects<br>Current best trial: 025f7_00000 with mse=0.7617445676142129 and parameters={'input_feature_num': None, 'output_feature_num': 1, 'past_seq_len': 50, 'future_seq_len': 1, 'lstm_hidden_dim': 16, 'lstm_layer_num': 1, 'lr': 0.001127486929663181, 'dropout': 0.05442452892887036, 'teacher_forcing': True, 'selected_features': [], 'batch_size': 16}<br>Result logdir: /tmp/autots_estimator/autots_estimator<br>Number of trials: 12/12 (8 PENDING, 4 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status  </th><th>loc           </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  dropout</th><th style="text-align: right;">        lr</th><th style="text-align: right;">  lstm_hidden_dim</th><th style="text-align: right;">  lstm_layer_num</th><th>teacher_forcing  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  best_mse</th><th style="text-align: right;">     mse</th></tr>
# </thead>
# <tbody>
# <tr><td>train_func_025f7_00000</td><td>RUNNING </td><td>172.28.0.2:694</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.0544245</td><td style="text-align: right;">0.00112749</td><td style="text-align: right;">               16</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">     1</td><td style="text-align: right;">         8.43483</td><td style="text-align: right;">  0.761745</td><td style="text-align: right;">0.761745</td></tr>
# <tr><td>train_func_025f7_00001</td><td>RUNNING </td><td>172.28.0.2:695</td><td style="text-align: right;">          64</td><td style="text-align: right;">0.159865 </td><td style="text-align: right;">0.00148101</td><td style="text-align: right;">               32</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">     2</td><td style="text-align: right;">         6.89504</td><td style="text-align: right;">  0.787992</td><td style="text-align: right;">0.787992</td></tr>
# <tr><td>train_func_025f7_00002</td><td>RUNNING </td><td>172.28.0.2:819</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.245262 </td><td style="text-align: right;">0.00105112</td><td style="text-align: right;">               64</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00003</td><td>RUNNING </td><td>172.28.0.2:821</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.214    </td><td style="text-align: right;">0.00139245</td><td style="text-align: right;">               16</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00004</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.283837 </td><td style="text-align: right;">0.00163116</td><td style="text-align: right;">               32</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00005</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.120595 </td><td style="text-align: right;">0.00414444</td><td style="text-align: right;">               64</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00006</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.104646 </td><td style="text-align: right;">0.00171333</td><td style="text-align: right;">               16</td><td style="text-align: right;">               1</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00007</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.228704 </td><td style="text-align: right;">0.00115328</td><td style="text-align: right;">               32</td><td style="text-align: right;">               1</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00008</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.290679 </td><td style="text-align: right;">0.00324824</td><td style="text-align: right;">               64</td><td style="text-align: right;">               1</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00009</td><td>PENDING </td><td>              </td><td style="text-align: right;">          64</td><td style="text-align: right;">0.107087 </td><td style="text-align: right;">0.00469466</td><td style="text-align: right;">               16</td><td style="text-align: right;">               2</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00010</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.0159359</td><td style="text-align: right;">0.00323255</td><td style="text-align: right;">               32</td><td style="text-align: right;">               2</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# <tr><td>train_func_025f7_00011</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.083808 </td><td style="text-align: right;">0.00105137</td><td style="text-align: right;">               64</td><td style="text-align: right;">               2</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">        </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-01-29 16:32:39 (running for 00:00:27.99)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 4.0/4 CPUs, 0/0 GPUs, 0.0/6.75 GiB heap, 0.0/3.37 GiB objects<br>Current best trial: 025f7_00001 with mse=0.0556474268718281 and parameters={'input_feature_num': None, 'output_feature_num': 1, 'past_seq_len': 50, 'future_seq_len': 1, 'lstm_hidden_dim': 32, 'lstm_layer_num': 1, 'lr': 0.0014810138683473604, 'dropout': 0.15986455572025818, 'teacher_forcing': True, 'selected_features': [], 'batch_size': 64}<br>Result logdir: /tmp/autots_estimator/autots_estimator<br>Number of trials: 12/12 (8 PENDING, 4 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status  </th><th>loc           </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  dropout</th><th style="text-align: right;">        lr</th><th style="text-align: right;">  lstm_hidden_dim</th><th style="text-align: right;">  lstm_layer_num</th><th>teacher_forcing  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  best_mse</th><th style="text-align: right;">      mse</th></tr>
# </thead>
# <tbody>
# <tr><td>train_func_025f7_00000</td><td>RUNNING </td><td>172.28.0.2:694</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.0544245</td><td style="text-align: right;">0.00112749</td><td style="text-align: right;">               16</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">     2</td><td style="text-align: right;">         19.5755</td><td style="text-align: right;"> 0.140914 </td><td style="text-align: right;">0.140914 </td></tr>
# <tr><td>train_func_025f7_00001</td><td>RUNNING </td><td>172.28.0.2:695</td><td style="text-align: right;">          64</td><td style="text-align: right;">0.159865 </td><td style="text-align: right;">0.00148101</td><td style="text-align: right;">               32</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">     4</td><td style="text-align: right;">         12.6404</td><td style="text-align: right;"> 0.0556474</td><td style="text-align: right;">0.0556474</td></tr>
# <tr><td>train_func_025f7_00002</td><td>RUNNING </td><td>172.28.0.2:819</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.245262 </td><td style="text-align: right;">0.00105112</td><td style="text-align: right;">               64</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# <tr><td>train_func_025f7_00003</td><td>RUNNING </td><td>172.28.0.2:821</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.214    </td><td style="text-align: right;">0.00139245</td><td style="text-align: right;">               16</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# <tr><td>train_func_025f7_00004</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.283837 </td><td style="text-align: right;">0.00163116</td><td style="text-align: right;">               32</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# <tr><td>train_func_025f7_00005</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.120595 </td><td style="text-align: right;">0.00414444</td><td style="text-align: right;">               64</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# <tr><td>train_func_025f7_00006</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.104646 </td><td style="text-align: right;">0.00171333</td><td style="text-align: right;">               16</td><td style="text-align: right;">               1</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# <tr><td>train_func_025f7_00007</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.228704 </td><td style="text-align: right;">0.00115328</td><td style="text-align: right;">               32</td><td style="text-align: right;">               1</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# <tr><td>train_func_025f7_00008</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.290679 </td><td style="text-align: right;">0.00324824</td><td style="text-align: right;">               64</td><td style="text-align: right;">               1</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# <tr><td>train_func_025f7_00009</td><td>PENDING </td><td>              </td><td style="text-align: right;">          64</td><td style="text-align: right;">0.107087 </td><td style="text-align: right;">0.00469466</td><td style="text-align: right;">               16</td><td style="text-align: right;">               2</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# <tr><td>train_func_025f7_00010</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.0159359</td><td style="text-align: right;">0.00323255</td><td style="text-align: right;">               32</td><td style="text-align: right;">               2</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# <tr><td>train_func_025f7_00011</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.083808 </td><td style="text-align: right;">0.00105137</td><td style="text-align: right;">               64</td><td style="text-align: right;">               2</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-01-29 16:32:45 (running for 00:00:33.34)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 4.0/4 CPUs, 0/0 GPUs, 0.0/6.75 GiB heap, 0.0/3.37 GiB objects<br>Current best trial: 025f7_00001 with mse=0.04517525071387338 and parameters={'input_feature_num': None, 'output_feature_num': 1, 'past_seq_len': 50, 'future_seq_len': 1, 'lstm_hidden_dim': 32, 'lstm_layer_num': 1, 'lr': 0.0014810138683473604, 'dropout': 0.15986455572025818, 'teacher_forcing': True, 'selected_features': [], 'batch_size': 64}<br>Result logdir: /tmp/autots_estimator/autots_estimator<br>Number of trials: 12/12 (8 PENDING, 4 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status  </th><th>loc           </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  dropout</th><th style="text-align: right;">        lr</th><th style="text-align: right;">  lstm_hidden_dim</th><th style="text-align: right;">  lstm_layer_num</th><th>teacher_forcing  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  best_mse</th><th style="text-align: right;">      mse</th></tr>
# </thead>
# <tbody>
# <tr><td>train_func_025f7_00000</td><td>RUNNING </td><td>172.28.0.2:694</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.0544245</td><td style="text-align: right;">0.00112749</td><td style="text-align: right;">               16</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">     3</td><td style="text-align: right;">         26.8022</td><td style="text-align: right;"> 0.0861385</td><td style="text-align: right;">0.0861385</td></tr>
# <tr><td>train_func_025f7_00001</td><td>RUNNING </td><td>172.28.0.2:695</td><td style="text-align: right;">          64</td><td style="text-align: right;">0.159865 </td><td style="text-align: right;">0.00148101</td><td style="text-align: right;">               32</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">     6</td><td style="text-align: right;">         19.0047</td><td style="text-align: right;"> 0.0371075</td><td style="text-align: right;">0.0451753</td></tr>
# <tr><td>train_func_025f7_00002</td><td>RUNNING </td><td>172.28.0.2:819</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.245262 </td><td style="text-align: right;">0.00105112</td><td style="text-align: right;">               64</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">     1</td><td style="text-align: right;">         11.2543</td><td style="text-align: right;"> 0.0557384</td><td style="text-align: right;">0.0557384</td></tr>
# <tr><td>train_func_025f7_00003</td><td>RUNNING </td><td>172.28.0.2:821</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.214    </td><td style="text-align: right;">0.00139245</td><td style="text-align: right;">               16</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">     1</td><td style="text-align: right;">         15.5316</td><td style="text-align: right;"> 0.381787 </td><td style="text-align: right;">0.381787 </td></tr>
# <tr><td>train_func_025f7_00004</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.283837 </td><td style="text-align: right;">0.00163116</td><td style="text-align: right;">               32</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# <tr><td>train_func_025f7_00005</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.120595 </td><td style="text-align: right;">0.00414444</td><td style="text-align: right;">               64</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# <tr><td>train_func_025f7_00006</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.104646 </td><td style="text-align: right;">0.00171333</td><td style="text-align: right;">               16</td><td style="text-align: right;">               1</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# <tr><td>train_func_025f7_00007</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.228704 </td><td style="text-align: right;">0.00115328</td><td style="text-align: right;">               32</td><td style="text-align: right;">               1</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# <tr><td>train_func_025f7_00008</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.290679 </td><td style="text-align: right;">0.00324824</td><td style="text-align: right;">               64</td><td style="text-align: right;">               1</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# <tr><td>train_func_025f7_00009</td><td>PENDING </td><td>              </td><td style="text-align: right;">          64</td><td style="text-align: right;">0.107087 </td><td style="text-align: right;">0.00469466</td><td style="text-align: right;">               16</td><td style="text-align: right;">               2</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# <tr><td>train_func_025f7_00010</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.0159359</td><td style="text-align: right;">0.00323255</td><td style="text-align: right;">               32</td><td style="text-align: right;">               2</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# <tr><td>train_func_025f7_00011</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.083808 </td><td style="text-align: right;">0.00105137</td><td style="text-align: right;">               64</td><td style="text-align: right;">               2</td><td>False            </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-01-29 16:32:50 (running for 00:00:38.93)<br>Memory usage on this node: 3.1/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 4.0/4 CPUs, 0/0 GPUs, 0.0/6.75 GiB heap, 0.0/3.37 GiB objects<br>Current best trial: 025f7_00002 with mse=0.02571042765758932 and parameters={'input_feature_num': None, 'output_feature_num': 1, 'past_seq_len': 50, 'future_seq_len': 1, 'lstm_hidden_dim': 64, 'lstm_layer_num': 1, 'lr': 0.0010511161555564336, 'dropout': 0.24526223963667237, 'teacher_forcing': True, 'selected_features': [], 'batch_size': 16}<br>Result logdir: /tmp/autots_estimator/autots_estimator<br>Number of trials: 12/12 (8 PENDING, 4 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status  </th><th>loc           </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  dropout</th><th style="text-align: right;">        lr</th><th style="text-align: right;">  lstm_hidden_dim</th><th style="text-align: right;">  lstm_layer_num</th><th>teacher_forcing  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  best_mse</th><th style="text-align: right;">      mse</th></tr>
# </thead>
# <tbody>
# <tr><td>train_func_025f7_00000</td><td>RUNNING </td><td>172.28.0.2:694</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.0544245</td><td style="text-align: right;">0.00112749</td><td style="text-align: right;">               16</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">     3</td><td style="text-align: right;">         26.8022</td><td style="text-align: right;"> 0.0861385</td><td style="text-align: right;">0.0861385</td></tr>
# <tr><td>train_func_025f7_00001</td><td>RUNNING </td><td>172.28.0.2:695</td><td style="text-align: right;">          64</td><td style="text-align: right;">0.159865 </td><td style="text-align: right;">0.00148101</td><td style="text-align: right;">               32</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">     7</td><td style="text-align: right;">         22.2459</td><td style="text-align: right;"> 0.0290169</td><td style="text-align: right;">0.0290169</td></tr>
# <tr><td>train_func_025f7_00002</td><td>RUNNING </td><td>172.28.0.2:819</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.245262 </td><td style="text-align: right;">0.00105112</td><td style="text-align: right;">               64</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">     2</td><td style="text-align: right;">         20.9022</td><td style="text-align: right;"> 0.0257104</td><td style="text-align: right;">0.0257104</td></tr>
# <tr><td>train_func_025f7_00003</td><td>RUNNING </td><td>172.28.0.2:821</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.214    </td><td style="text-align: right;">0.00139245</td><td style="text-align: right;">               16</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">     1</td><td style="text-align: right;">         15.5316</td><td style="text-align: right;"> 0.381787 </td><td style="text-align: right;">0.381787 </td></tr>
# <tr><td>train_func_025f7_00004</td><td>PENDING </td><td>              </td><td style="text-align: right;">          16</td><td style="text-align: right;">0.283837 </td><td style="text-align: right;">0.00163116</td><td style="text-align: right;">               32</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# <tr><td>train_func_025f7_00005</td><td>PENDING </td><td>              </td><td style="text-align: right;">          32</td><td style="text-align: right;">0.120595 </td><td style="text-align: right;">0.00414444</td><td style="text-align: right;">               64</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">          </td><td style="text-align: right;">         </td></tr>
# ...
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-01-29 16:48:38 (running for 00:16:26.59)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 2.0/4 CPUs, 0/0 GPUs, 0.0/6.75 GiB heap, 0.0/3.37 GiB objects<br>Current best trial: 025f7_00008 with mse=0.008736356655316432 and parameters={'input_feature_num': None, 'output_feature_num': 1, 'past_seq_len': 50, 'future_seq_len': 1, 'lstm_hidden_dim': 64, 'lstm_layer_num': 1, 'lr': 0.0032482400496749737, 'dropout': 0.290678911277962, 'teacher_forcing': False, 'selected_features': [], 'batch_size': 32}<br>Result logdir: /tmp/autots_estimator/autots_estimator<br>Number of trials: 12/12 (2 RUNNING, 10 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status    </th><th>loc           </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  dropout</th><th style="text-align: right;">        lr</th><th style="text-align: right;">  lstm_hidden_dim</th><th style="text-align: right;">  lstm_layer_num</th><th>teacher_forcing  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  best_mse</th><th style="text-align: right;">       mse</th></tr>
# </thead>
# <tbody>
# <tr><td>train_func_025f7_00010</td><td>RUNNING   </td><td>172.28.0.2:821</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.0159359</td><td style="text-align: right;">0.00323255</td><td style="text-align: right;">               32</td><td style="text-align: right;">               2</td><td>False            </td><td style="text-align: right;">    49</td><td style="text-align: right;">         313.272</td><td style="text-align: right;">0.0126685 </td><td style="text-align: right;">0.0278209 </td></tr>
# <tr><td>train_func_025f7_00011</td><td>RUNNING   </td><td>172.28.0.2:694</td><td style="text-align: right;">          32</td><td style="text-align: right;">0.083808 </td><td style="text-align: right;">0.00105137</td><td style="text-align: right;">               64</td><td style="text-align: right;">               2</td><td>False            </td><td style="text-align: right;">    49</td><td style="text-align: right;">         254.262</td><td style="text-align: right;">0.0101507 </td><td style="text-align: right;">0.0178565 </td></tr>
# <tr><td>train_func_025f7_00000</td><td>TERMINATED</td><td>172.28.0.2:694</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.0544245</td><td style="text-align: right;">0.00112749</td><td style="text-align: right;">               16</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">    50</td><td style="text-align: right;">         279.97 </td><td style="text-align: right;">0.0104781 </td><td style="text-align: right;">0.0113643 </td></tr>
# <tr><td>train_func_025f7_00001</td><td>TERMINATED</td><td>172.28.0.2:695</td><td style="text-align: right;">          64</td><td style="text-align: right;">0.159865 </td><td style="text-align: right;">0.00148101</td><td style="text-align: right;">               32</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">    50</td><td style="text-align: right;">         115.608</td><td style="text-align: right;">0.0113362 </td><td style="text-align: right;">0.0137034 </td></tr>
# <tr><td>train_func_025f7_00002</td><td>TERMINATED</td><td>172.28.0.2:819</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.245262 </td><td style="text-align: right;">0.00105112</td><td style="text-align: right;">               64</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">    50</td><td style="text-align: right;">         354.48 </td><td style="text-align: right;">0.00845337</td><td style="text-align: right;">0.0244881 </td></tr>
# <tr><td>train_func_025f7_00003</td><td>TERMINATED</td><td>172.28.0.2:821</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.214    </td><td style="text-align: right;">0.00139245</td><td style="text-align: right;">               16</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">    50</td><td style="text-align: right;">         506.168</td><td style="text-align: right;">0.0341224 </td><td style="text-align: right;">0.0512065 </td></tr>
# <tr><td>train_func_025f7_00004</td><td>TERMINATED</td><td>172.28.0.2:695</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.283837 </td><td style="text-align: right;">0.00163116</td><td style="text-align: right;">               32</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">    50</td><td style="text-align: right;">         530.206</td><td style="text-align: right;">0.0170655 </td><td style="text-align: right;">0.0464657 </td></tr>
# <tr><td>train_func_025f7_00005</td><td>TERMINATED</td><td>172.28.0.2:694</td><td style="text-align: right;">          32</td><td style="text-align: right;">0.120595 </td><td style="text-align: right;">0.00414444</td><td style="text-align: right;">               64</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">    50</td><td style="text-align: right;">         444.605</td><td style="text-align: right;">0.0124409 </td><td style="text-align: right;">0.0124409 </td></tr>
# <tr><td>train_func_025f7_00006</td><td>TERMINATED</td><td>172.28.0.2:819</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.104646 </td><td style="text-align: right;">0.00171333</td><td style="text-align: right;">               16</td><td style="text-align: right;">               1</td><td>False            </td><td style="text-align: right;">    50</td><td style="text-align: right;">         236.616</td><td style="text-align: right;">0.00978472</td><td style="text-align: right;">0.0104539 </td></tr>
# <tr><td>train_func_025f7_00007</td><td>TERMINATED</td><td>172.28.0.2:821</td><td style="text-align: right;">          32</td><td style="text-align: right;">0.228704 </td><td style="text-align: right;">0.00115328</td><td style="text-align: right;">               32</td><td style="text-align: right;">               1</td><td>False            </td><td style="text-align: right;">    50</td><td style="text-align: right;">         150.182</td><td style="text-align: right;">0.0093948 </td><td style="text-align: right;">0.00982863</td></tr>
# <tr><td>train_func_025f7_00008</td><td>TERMINATED</td><td>172.28.0.2:819</td><td style="text-align: right;">          32</td><td style="text-align: right;">0.290679 </td><td style="text-align: right;">0.00324824</td><td style="text-align: right;">               64</td><td style="text-align: right;">               1</td><td>False            </td><td style="text-align: right;">    50</td><td style="text-align: right;">         210.305</td><td style="text-align: right;">0.00843569</td><td style="text-align: right;">0.00873636</td></tr>
# <tr><td>train_func_025f7_00009</td><td>TERMINATED</td><td>172.28.0.2:695</td><td style="text-align: right;">          64</td><td style="text-align: right;">0.107087 </td><td style="text-align: right;">0.00469466</td><td style="text-align: right;">               16</td><td style="text-align: right;">               2</td><td>False            </td><td style="text-align: right;">    50</td><td style="text-align: right;">         159.344</td><td style="text-align: right;">0.0192036 </td><td style="text-align: right;">0.0248151 </td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-01-29 16:48:42 (running for 00:16:30.01)<br>Memory usage on this node: 2.5/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/4 CPUs, 0/0 GPUs, 0.0/6.75 GiB heap, 0.0/3.37 GiB objects<br>Current best trial: 025f7_00008 with mse=0.008736356655316432 and parameters={'input_feature_num': None, 'output_feature_num': 1, 'past_seq_len': 50, 'future_seq_len': 1, 'lstm_hidden_dim': 64, 'lstm_layer_num': 1, 'lr': 0.0032482400496749737, 'dropout': 0.290678911277962, 'teacher_forcing': False, 'selected_features': [], 'batch_size': 32}<br>Result logdir: /tmp/autots_estimator/autots_estimator<br>Number of trials: 12/12 (12 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name            </th><th>status    </th><th>loc           </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  dropout</th><th style="text-align: right;">        lr</th><th style="text-align: right;">  lstm_hidden_dim</th><th style="text-align: right;">  lstm_layer_num</th><th>teacher_forcing  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  best_mse</th><th style="text-align: right;">       mse</th></tr>
# </thead>
# <tbody>
# <tr><td>train_func_025f7_00000</td><td>TERMINATED</td><td>172.28.0.2:694</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.0544245</td><td style="text-align: right;">0.00112749</td><td style="text-align: right;">               16</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">    50</td><td style="text-align: right;">         279.97 </td><td style="text-align: right;">0.0104781 </td><td style="text-align: right;">0.0113643 </td></tr>
# <tr><td>train_func_025f7_00001</td><td>TERMINATED</td><td>172.28.0.2:695</td><td style="text-align: right;">          64</td><td style="text-align: right;">0.159865 </td><td style="text-align: right;">0.00148101</td><td style="text-align: right;">               32</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">    50</td><td style="text-align: right;">         115.608</td><td style="text-align: right;">0.0113362 </td><td style="text-align: right;">0.0137034 </td></tr>
# <tr><td>train_func_025f7_00002</td><td>TERMINATED</td><td>172.28.0.2:819</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.245262 </td><td style="text-align: right;">0.00105112</td><td style="text-align: right;">               64</td><td style="text-align: right;">               1</td><td>True             </td><td style="text-align: right;">    50</td><td style="text-align: right;">         354.48 </td><td style="text-align: right;">0.00845337</td><td style="text-align: right;">0.0244881 </td></tr>
# <tr><td>train_func_025f7_00003</td><td>TERMINATED</td><td>172.28.0.2:821</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.214    </td><td style="text-align: right;">0.00139245</td><td style="text-align: right;">               16</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">    50</td><td style="text-align: right;">         506.168</td><td style="text-align: right;">0.0341224 </td><td style="text-align: right;">0.0512065 </td></tr>
# <tr><td>train_func_025f7_00004</td><td>TERMINATED</td><td>172.28.0.2:695</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.283837 </td><td style="text-align: right;">0.00163116</td><td style="text-align: right;">               32</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">    50</td><td style="text-align: right;">         530.206</td><td style="text-align: right;">0.0170655 </td><td style="text-align: right;">0.0464657 </td></tr>
# <tr><td>train_func_025f7_00005</td><td>TERMINATED</td><td>172.28.0.2:694</td><td style="text-align: right;">          32</td><td style="text-align: right;">0.120595 </td><td style="text-align: right;">0.00414444</td><td style="text-align: right;">               64</td><td style="text-align: right;">               2</td><td>True             </td><td style="text-align: right;">    50</td><td style="text-align: right;">         444.605</td><td style="text-align: right;">0.0124409 </td><td style="text-align: right;">0.0124409 </td></tr>
# <tr><td>train_func_025f7_00006</td><td>TERMINATED</td><td>172.28.0.2:819</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.104646 </td><td style="text-align: right;">0.00171333</td><td style="text-align: right;">               16</td><td style="text-align: right;">               1</td><td>False            </td><td style="text-align: right;">    50</td><td style="text-align: right;">         236.616</td><td style="text-align: right;">0.00978472</td><td style="text-align: right;">0.0104539 </td></tr>
# <tr><td>train_func_025f7_00007</td><td>TERMINATED</td><td>172.28.0.2:821</td><td style="text-align: right;">          32</td><td style="text-align: right;">0.228704 </td><td style="text-align: right;">0.00115328</td><td style="text-align: right;">               32</td><td style="text-align: right;">               1</td><td>False            </td><td style="text-align: right;">    50</td><td style="text-align: right;">         150.182</td><td style="text-align: right;">0.0093948 </td><td style="text-align: right;">0.00982863</td></tr>
# <tr><td>train_func_025f7_00008</td><td>TERMINATED</td><td>172.28.0.2:819</td><td style="text-align: right;">          32</td><td style="text-align: right;">0.290679 </td><td style="text-align: right;">0.00324824</td><td style="text-align: right;">               64</td><td style="text-align: right;">               1</td><td>False            </td><td style="text-align: right;">    50</td><td style="text-align: right;">         210.305</td><td style="text-align: right;">0.00843569</td><td style="text-align: right;">0.00873636</td></tr>
# <tr><td>train_func_025f7_00009</td><td>TERMINATED</td><td>172.28.0.2:695</td><td style="text-align: right;">          64</td><td style="text-align: right;">0.107087 </td><td style="text-align: right;">0.00469466</td><td style="text-align: right;">               16</td><td style="text-align: right;">               2</td><td>False            </td><td style="text-align: right;">    50</td><td style="text-align: right;">         159.344</td><td style="text-align: right;">0.0192036 </td><td style="text-align: right;">0.0248151 </td></tr>
# <tr><td>train_func_025f7_00010</td><td>TERMINATED</td><td>172.28.0.2:821</td><td style="text-align: right;">          16</td><td style="text-align: right;">0.0159359</td><td style="text-align: right;">0.00323255</td><td style="text-align: right;">               32</td><td style="text-align: right;">               2</td><td>False            </td><td style="text-align: right;">    50</td><td style="text-align: right;">         316.676</td><td style="text-align: right;">0.0126685 </td><td style="text-align: right;">0.0171782 </td></tr>
# <tr><td>train_func_025f7_00011</td><td>TERMINATED</td><td>172.28.0.2:694</td><td style="text-align: right;">          32</td><td style="text-align: right;">0.083808 </td><td style="text-align: right;">0.00105137</td><td style="text-align: right;">               64</td><td style="text-align: right;">               2</td><td>False            </td><td style="text-align: right;">    50</td><td style="text-align: right;">         258.542</td><td style="text-align: right;">0.0101507 </td><td style="text-align: right;">0.0132335 </td></tr>
# </tbody>
# </table><br><br>
# 2022-01-29 16:48:42,126	INFO tune.py:626 -- Total run time: 990.67 seconds (989.99 seconds for the tuning loop).
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py:65: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.290678911277962 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %% [markdown]
# ### **Step 5: Further deployment with TSPipeline**

# %% [markdown]
# [TSPipeline](https://analytics-zoo.readthedocs.io/en/latest/doc/PythonAPI/Chronos/autotsestimator.html#tspipeline-experimental) is our E2E solution for time series forecasting task.

# %%
# predict with the best trial
y_pred = ts_pipeline.predict(tsdata_test)

# %%
# evaluate the result pipeline
mse, smape, r2, rmse, mape = ts_pipeline.evaluate(tsdata_test, metrics=["mse", "smape", "r2", "rmse", "mape"])
print("Evaluate: the mean square error is", mse)
print("Evaluate: the smape value is", smape)
print("Evaluate: the r2 value is", r2)
print("Evaluate: the rmse value is", rmse)
print("Evaluate: the mape value is", mape)


# # save the pipeline
# my_ppl_file_path = "/tmp/saved_pipeline"
# ts_pipeline.save(my_ppl_file_path)

# # restore the pipeline for further deployment
# from bigdl.chronos.autots import TSPipeline
# loaded_ppl = TSPipeline.load(my_ppl_file_path)
# Out:
# Evaluate: the mean square error is 5.706465892916146
# Evaluate: the smape value is 0.013910057603961959
# Evaluate: the r2 value is 0.907239744072107
# Evaluate: the rmse value is 2.3888210257187845
# Evaluate: the mape value is 0.01407925548583487

# %%
best_config = auto_estimator.get_best_config()
print(best_config)
# Out:
# {'input_feature_num': 1, 'output_feature_num': 1, 'past_seq_len': 50, 'future_seq_len': 1, 'lstm_hidden_dim': 64, 'lstm_layer_num': 1, 'lr': 0.0032482400496749737, 'dropout': 0.290678911277962, 'teacher_forcing': False, 'selected_features': [], 'batch_size': 32}

# %%
# plot the result
import matplotlib.pyplot as plt

lookback = auto_estimator.get_best_config()['past_seq_len']
groundtruth_unscale = tsdata_test.unscale().to_pandas()[lookback - 1:]

plt.figure(figsize=(10,5))
plt.plot(groundtruth_unscale["date"], groundtruth_unscale["close"], color='blue', label="VCB daily price Raw")
plt.plot(groundtruth_unscale["date"], y_pred[:,0,0], color='red', label="VCB daily price Predicted")
plt.xlabel("Time Period")
plt.ylabel("Normalized Stock Price")
plt.legend()
plt.show()

# %%
# # save the pipeline
# my_ppl_file_path = "/tmp/saved_pipeline"
# ts_pipeline.save(my_ppl_file_path)

# %%
# # restore the pipeline for further deployment
# from bigdl.chronos.autots import TSPipeline
# loaded_ppl = TSPipeline.load(my_ppl_file_path)

# %%
# # Stop orca context when your program finishes
# stop_orca_context()

# %%
# # show a tensorboard view
# %load_ext tensorboard
# %tensorboard --logdir /tmp/autots_estimator/autots_estimator_leaderboard/
